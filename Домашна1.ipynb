# %% [markdown]
# <a href="https://colab.research.google.com/github/MajorMissaMissa/dians-/blob/main/%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
from tqdm import tqdm
import time
from google.colab import files

start_date = datetime(2014, 1, 1)
end_date = datetime(2024, 10, 31)

data_frames = []

session = requests.Session()

current_date = start_date
date_range = (end_date - start_date).days + 1

for _ in tqdm(range(date_range), desc="Downloading data"):
    date_str = current_date.strftime('%Y-%m-%d')

    url = f"https://www.mse.mk/daily/stats/symbolhistory/REPL?date={date_str}"


    for attempt in range(3):
        try:
            response = session.get(url, timeout=10)
            if response.status_code == 200:
                df = pd.read_html(response.content)[0]
                data_frames.append(df)
                print(f"Data for {date_str} downloaded successfully.")
                break
            else:
                print(f"Failed to download data for {date_str}. Status code: {response.status_code}")
        except Exception as e:
            print(f"Error downloading data for {date_str}: {e}")
            time.sleep(1)
    else:
        print(f"Failed to download data for {date_str} after 3 attempts.")


    current_date += timedelta(days=1)


if data_frames:
    all_data = pd.concat(data_frames, ignore_index=True)
    csv_file_path = "/content/historical_data.csv"
    all_data.to_csv(csv_file_path, index=False)
    print("Data saved to historical_data.csv")


    files.download(csv_file_path)
else:
    print("No data downloaded.")
# Out:
# Downloading data:   0%|          | 1/3957 [00:00<1:03:07,  1.04it/s]
# Data for 2014-01-01 downloaded successfully.
# Downloading data:   0%|          | 2/3957 [00:01<39:15,  1.68it/s]
# Data for 2014-01-02 downloaded successfully.
# Downloading data:   0%|          | 3/3957 [00:01<27:50,  2.37it/s]
# Data for 2014-01-03 downloaded successfully.
# Downloading data:   0%|          | 4/3957 [00:01<24:20,  2.71it/s]
# Data for 2014-01-04 downloaded successfully.
# Downloading data:   0%|          | 5/3957 [00:02<20:57,  3.14it/s]
# Data for 2014-01-05 downloaded successfully.
# Downloading data:   0%|          | 7/3957 [00:02<17:03,  3.86it/s]
# Data for 2014-01-06 downloaded successfully.
# Data for 2014-01-07 downloaded successfully.
# Downloading data:   0%|          | 8/3957 [00:02<16:26,  4.00it/s]
# Data for 2014-01-08 downloaded successfully.
# Downloading data:   0%|          | 10/3957 [00:03<14:33,  4.52it/s]
# Data for 2014-01-09 downloaded successfully.
# Data for 2014-01-10 downloaded successfully.
# Downloading data:   0%|          | 12/3957 [00:03<14:14,  4.62it/s]
# Data for 2014-01-11 downloaded successfully.
# Data for 2014-01-12 downloaded successfully.
# Downloading data:   0%|          | 13/3957 [00:03<14:45,  4.46it/s]
# Data for 2014-01-13 downloaded successfully.
# Data for 2014-01-14 downloaded successfully.
# Downloading data:   0%|          | 14/3957 [00:03<14:25,  4.56it/s]
# Downloading data:   0%|          | 15/3957 [00:04<15:51,  4.14it/s]
# Data for 2014-01-15 downloaded successfully.
# Downloading data:   0%|          | 16/3957 [00:04<15:44,  4.17it/s]
# Data for 2014-01-16 downloaded successfully.
# Downloading data:   0%|          | 17/3957 [00:04<15:15,  4.30it/s]
# Data for 2014-01-17 downloaded successfully.
# Downloading data:   0%|          | 19/3957 [00:05<14:10,  4.63it/s]
# Data for 2014-01-18 downloaded successfully.
# Data for 2014-01-19 downloaded successfully.
# Downloading data:   1%|          | 21/3957 [00:05<13:41,  4.79it/s]
# Data for 2014-01-20 downloaded successfully.
# Data for 2014-01-21 downloaded successfully.
# Downloading data:   1%|          | 23/3957 [00:05<13:41,  4.79it/s]
# Data for 2014-01-22 downloaded successfully.
# Data for 2014-01-23 downloaded successfully.
# Downloading data:   1%|          | 25/3957 [00:06<13:14,  4.95it/s]
# Data for 2014-01-24 downloaded successfully.
# Data for 2014-01-25 downloaded successfully.
# Downloading data:   1%|          | 26/3957 [00:06<13:32,  4.84it/s]
# Data for 2014-01-26 downloaded successfully.
# Downloading data:   1%|          | 27/3957 [00:06<13:49,  4.74it/s]
# Data for 2014-01-27 downloaded successfully.
# Downloading data:   1%|          | 28/3957 [00:06<13:52,  4.72it/s]
# Data for 2014-01-28 downloaded successfully.
# Downloading data:   1%|          | 29/3957 [00:07<13:45,  4.76it/s]
# Data for 2014-01-29 downloaded successfully.
# Downloading data:   1%|          | 30/3957 [00:07<13:54,  4.70it/s]
# Data for 2014-01-30 downloaded successfully.
# Downloading data:   1%|          | 32/3957 [00:07<13:25,  4.87it/s]
# Data for 2014-01-31 downloaded successfully.
# Data for 2014-02-01 downloaded successfully.
# Downloading data:   1%|          | 33/3957 [00:08<13:29,  4.85it/s]
# Data for 2014-02-02 downloaded successfully.
# Data for 2014-02-03 downloaded successfully.
# Downloading data:   1%|          | 34/3957 [00:08<13:19,  4.90it/s]
# Data for 2014-02-04 downloaded successfully.
# Downloading data:   1%|          | 37/3957 [00:08<12:50,  5.09it/s]
# Data for 2014-02-05 downloaded successfully.
# Data for 2014-02-06 downloaded successfully.
# Downloading data:   1%|          | 38/3957 [00:09<13:12,  4.94it/s]
# Data for 2014-02-07 downloaded successfully.
# Downloading data:   1%|          | 40/3957 [00:09<13:09,  4.96it/s]
# Data for 2014-02-08 downloaded successfully.
# Data for 2014-02-09 downloaded successfully.
# Downloading data:   1%|          | 42/3957 [00:09<12:03,  5.41it/s]
# Data for 2014-02-10 downloaded successfully.
# Data for 2014-02-11 downloaded successfully.
# Downloading data:   1%|          | 44/3957 [00:10<12:17,  5.30it/s]
# Data for 2014-02-12 downloaded successfully.
# Data for 2014-02-13 downloaded successfully.
# Downloading data:   1%|          | 46/3957 [00:10<11:43,  5.56it/s]
# Data for 2014-02-14 downloaded successfully.
# Data for 2014-02-15 downloaded successfully.
# Downloading data:   1%|          | 48/3957 [00:10<11:23,  5.72it/s]
# Data for 2014-02-16 downloaded successfully.
# Data for 2014-02-17 downloaded successfully.
# Downloading data:   1%|▏         | 50/3957 [00:11<11:17,  5.76it/s]
# Data for 2014-02-18 downloaded successfully.
# Data for 2014-02-19 downloaded successfully.
# Downloading data:   1%|▏         | 52/3957 [00:11<11:03,  5.89it/s]
# Data for 2014-02-20 downloaded successfully.
# Data for 2014-02-21 downloaded successfully.
# Downloading data:   1%|▏         | 54/3957 [00:11<11:07,  5.85it/s]
# Data for 2014-02-22 downloaded successfully.
# Data for 2014-02-23 downloaded successfully.
# Downloading data:   1%|▏         | 56/3957 [00:12<11:06,  5.85it/s]
# Data for 2014-02-24 downloaded successfully.
# Data for 2014-02-25 downloaded successfully.
# Downloading data:   1%|▏         | 58/3957 [00:12<11:30,  5.65it/s]
# Data for 2014-02-26 downloaded successfully.
# Data for 2014-02-27 downloaded successfully.
# Downloading data:   2%|▏         | 60/3957 [00:12<11:42,  5.54it/s]
# Data for 2014-02-28 downloaded successfully.
# Data for 2014-03-01 downloaded successfully.
# Downloading data:   2%|▏         | 62/3957 [00:13<11:26,  5.68it/s]
# Data for 2014-03-02 downloaded successfully.
# Data for 2014-03-03 downloaded successfully.
# Downloading data:   2%|▏         | 64/3957 [00:13<11:19,  5.73it/s]
# Data for 2014-03-04 downloaded successfully.
# Data for 2014-03-05 downloaded successfully.
# Downloading data:   2%|▏         | 66/3957 [00:13<11:14,  5.77it/s]
# Data for 2014-03-06 downloaded successfully.
# Data for 2014-03-07 downloaded successfully.
# Downloading data:   2%|▏         | 68/3957 [00:14<11:56,  5.43it/s]
# Data for 2014-03-08 downloaded successfully.
# Data for 2014-03-09 downloaded successfully.
# Downloading data:   2%|▏         | 70/3957 [00:14<11:41,  5.54it/s]
# Data for 2014-03-10 downloaded successfully.
# Data for 2014-03-11 downloaded successfully.
# Downloading data:   2%|▏         | 72/3957 [00:15<11:47,  5.49it/s]
# Data for 2014-03-12 downloaded successfully.
# Data for 2014-03-13 downloaded successfully.
# Downloading data:   2%|▏         | 74/3957 [00:15<11:48,  5.48it/s]
# Data for 2014-03-14 downloaded successfully.
# Data for 2014-03-15 downloaded successfully.
# Downloading data:   2%|▏         | 76/3957 [00:15<11:31,  5.62it/s]
# Data for 2014-03-16 downloaded successfully.
# Data for 2014-03-17 downloaded successfully.
# Downloading data:   2%|▏         | 78/3957 [00:16<11:21,  5.69it/s]
# Data for 2014-03-18 downloaded successfully.
# Data for 2014-03-19 downloaded successfully.
# Downloading data:   2%|▏         | 80/3957 [00:16<11:40,  5.53it/s]
# Data for 2014-03-20 downloaded successfully.
# Data for 2014-03-21 downloaded successfully.
# Downloading data:   2%|▏         | 82/3957 [00:16<11:23,  5.67it/s]
# Data for 2014-03-22 downloaded successfully.
# Data for 2014-03-23 downloaded successfully.
# Downloading data:   2%|▏         | 84/3957 [00:17<11:17,  5.72it/s]
# Data for 2014-03-24 downloaded successfully.
# Data for 2014-03-25 downloaded successfully.
# Downloading data:   2%|▏         | 86/3957 [00:17<11:25,  5.65it/s]
# Data for 2014-03-26 downloaded successfully.
# Data for 2014-03-27 downloaded successfully.
# Downloading data:   2%|▏         | 88/3957 [00:17<11:27,  5.63it/s]
# Data for 2014-03-28 downloaded successfully.
# Data for 2014-03-29 downloaded successfully.
# Downloading data:   2%|▏         | 90/3957 [00:18<11:28,  5.62it/s]
# Data for 2014-03-30 downloaded successfully.
# Data for 2014-03-31 downloaded successfully.
# Downloading data:   2%|▏         | 92/3957 [00:18<11:48,  5.46it/s]
# Data for 2014-04-01 downloaded successfully.
# Data for 2014-04-02 downloaded successfully.
# Downloading data:   2%|▏         | 94/3957 [00:19<11:46,  5.47it/s]
# Data for 2014-04-03 downloaded successfully.
# Data for 2014-04-04 downloaded successfully.
# Downloading data:   2%|▏         | 96/3957 [00:19<11:19,  5.69it/s]
# Data for 2014-04-05 downloaded successfully.
# Data for 2014-04-06 downloaded successfully.
# Downloading data:   2%|▏         | 98/3957 [00:19<11:09,  5.76it/s]
# Data for 2014-04-07 downloaded successfully.
# Data for 2014-04-08 downloaded successfully.
# Downloading data:   3%|▎         | 100/3957 [00:20<11:04,  5.81it/s]
# Data for 2014-04-09 downloaded successfully.
# Data for 2014-04-10 downloaded successfully.
# Downloading data:   3%|▎         | 102/3957 [00:20<11:19,  5.68it/s]
# Data for 2014-04-11 downloaded successfully.
# Data for 2014-04-12 downloaded successfully.
# Downloading data:   3%|▎         | 103/3957 [00:20<11:09,  5.76it/s]
# Data for 2014-04-13 downloaded successfully.
# Downloading data:   3%|▎         | 105/3957 [00:20<11:42,  5.48it/s]
# Data for 2014-04-14 downloaded successfully.
# Data for 2014-04-15 downloaded successfully.
# Downloading data:   3%|▎         | 107/3957 [00:21<11:31,  5.57it/s]
# Data for 2014-04-16 downloaded successfully.
# Data for 2014-04-17 downloaded successfully.
# Downloading data:   3%|▎         | 109/3957 [00:21<11:23,  5.63it/s]
# Data for 2014-04-18 downloaded successfully.
# Data for 2014-04-19 downloaded successfully.
# Downloading data:   3%|▎         | 111/3957 [00:22<11:46,  5.45it/s]
# Data for 2014-04-20 downloaded successfully.
# Data for 2014-04-21 downloaded successfully.
# Downloading data:   3%|▎         | 113/3957 [00:22<11:14,  5.70it/s]
# Data for 2014-04-22 downloaded successfully.
# Data for 2014-04-23 downloaded successfully.
# Downloading data:   3%|▎         | 115/3957 [00:22<11:03,  5.79it/s]
# Data for 2014-04-24 downloaded successfully.
# Data for 2014-04-25 downloaded successfully.
# Downloading data:   3%|▎         | 117/3957 [00:23<10:48,  5.92it/s]
# Data for 2014-04-26 downloaded successfully.
# Data for 2014-04-27 downloaded successfully.
# Downloading data:   3%|▎         | 118/3957 [00:23<11:06,  5.76it/s]
# Data for 2014-04-28 downloaded successfully.
# Downloading data:   3%|▎         | 120/3957 [00:23<11:30,  5.56it/s]
# Data for 2014-04-29 downloaded successfully.
# Data for 2014-04-30 downloaded successfully.
# Downloading data:   3%|▎         | 122/3957 [00:23<11:05,  5.76it/s]
# Data for 2014-05-01 downloaded successfully.
# Data for 2014-05-02 downloaded successfully.
# Downloading data:   3%|▎         | 124/3957 [00:24<11:12,  5.70it/s]
# Data for 2014-05-03 downloaded successfully.
# Data for 2014-05-04 downloaded successfully.
# Downloading data:   3%|▎         | 126/3957 [00:24<11:09,  5.72it/s]
# Data for 2014-05-05 downloaded successfully.
# Data for 2014-05-06 downloaded successfully.
# Downloading data:   3%|▎         | 128/3957 [00:24<10:47,  5.92it/s]
# Data for 2014-05-07 downloaded successfully.
# Data for 2014-05-08 downloaded successfully.
# Downloading data:   3%|▎         | 130/3957 [00:25<10:41,  5.96it/s]
# Data for 2014-05-09 downloaded successfully.
# Data for 2014-05-10 downloaded successfully.
# Downloading data:   3%|▎         | 132/3957 [00:25<10:34,  6.02it/s]
# Data for 2014-05-11 downloaded successfully.
# Data for 2014-05-12 downloaded successfully.
# Downloading data:   3%|▎         | 134/3957 [00:25<10:35,  6.02it/s]
# Data for 2014-05-13 downloaded successfully.
# Data for 2014-05-14 downloaded successfully.
# Downloading data:   3%|▎         | 136/3957 [00:26<10:32,  6.04it/s]
# Data for 2014-05-15 downloaded successfully.
# Data for 2014-05-16 downloaded successfully.
# Downloading data:   3%|▎         | 138/3957 [00:26<10:44,  5.93it/s]
# Data for 2014-05-17 downloaded successfully.
# Data for 2014-05-18 downloaded successfully.
# Downloading data:   4%|▎         | 140/3957 [00:26<10:36,  6.00it/s]
# Data for 2014-05-19 downloaded successfully.
# Data for 2014-05-20 downloaded successfully.
# Downloading data:   4%|▎         | 142/3957 [00:27<10:40,  5.96it/s]
# Data for 2014-05-21 downloaded successfully.
# Data for 2014-05-22 downloaded successfully.
# Downloading data:   4%|▎         | 144/3957 [00:27<10:35,  6.00it/s]
# Data for 2014-05-23 downloaded successfully.
# Data for 2014-05-24 downloaded successfully.
# Downloading data:   4%|▎         | 146/3957 [00:27<10:37,  5.98it/s]
# Data for 2014-05-25 downloaded successfully.
# Data for 2014-05-26 downloaded successfully.
# Downloading data:   4%|▎         | 148/3957 [00:28<10:34,  6.01it/s]
# Data for 2014-05-27 downloaded successfully.
# Data for 2014-05-28 downloaded successfully.
# Downloading data:   4%|▍         | 150/3957 [00:28<10:37,  5.97it/s]
# Data for 2014-05-29 downloaded successfully.
# Data for 2014-05-30 downloaded successfully.
# Downloading data:   4%|▍         | 152/3957 [00:28<10:39,  5.95it/s]
# Data for 2014-05-31 downloaded successfully.
# Data for 2014-06-01 downloaded successfully.
# Downloading data:   4%|▍         | 154/3957 [00:29<10:38,  5.96it/s]
# Data for 2014-06-02 downloaded successfully.
# Data for 2014-06-03 downloaded successfully.
# Downloading data:   4%|▍         | 156/3957 [00:29<11:02,  5.73it/s]
# Data for 2014-06-04 downloaded successfully.
# Data for 2014-06-05 downloaded successfully.
# Downloading data:   4%|▍         | 158/3957 [00:30<11:09,  5.68it/s]
# Data for 2014-06-06 downloaded successfully.
# Data for 2014-06-07 downloaded successfully.
# Downloading data:   4%|▍         | 159/3957 [00:30<11:27,  5.52it/s]
# Data for 2014-06-08 downloaded successfully.
# Data for 2014-06-09 downloaded successfully.
# Downloading data:   4%|▍         | 161/3957 [00:30<11:38,  5.43it/s]
# Data for 2014-06-10 downloaded successfully.
# Downloading data:   4%|▍         | 163/3957 [00:30<11:24,  5.54it/s]
# Data for 2014-06-11 downloaded successfully.
# Data for 2014-06-12 downloaded successfully.
# Downloading data:   4%|▍         | 165/3957 [00:31<10:57,  5.77it/s]
# Data for 2014-06-13 downloaded successfully.
# Data for 2014-06-14 downloaded successfully.
# Downloading data:   4%|▍         | 167/3957 [00:31<10:41,  5.91it/s]
# Data for 2014-06-15 downloaded successfully.
# Data for 2014-06-16 downloaded successfully.
# Downloading data:   4%|▍         | 169/3957 [00:31<10:33,  5.98it/s]
# Data for 2014-06-17 downloaded successfully.
# Data for 2014-06-18 downloaded successfully.
# Downloading data:   4%|▍         | 171/3957 [00:32<10:27,  6.03it/s]
# Data for 2014-06-19 downloaded successfully.
# Data for 2014-06-20 downloaded successfully.
# Downloading data:   4%|▍         | 173/3957 [00:32<10:31,  5.99it/s]
# Data for 2014-06-21 downloaded successfully.
# Data for 2014-06-22 downloaded successfully.
# Downloading data:   4%|▍         | 175/3957 [00:32<11:02,  5.70it/s]
# Data for 2014-06-23 downloaded successfully.
# Data for 2014-06-24 downloaded successfully.
# Downloading data:   4%|▍         | 177/3957 [00:33<11:01,  5.71it/s]
# Data for 2014-06-25 downloaded successfully.
# Data for 2014-06-26 downloaded successfully.
# Downloading data:   5%|▍         | 179/3957 [00:33<11:00,  5.72it/s]
# Data for 2014-06-27 downloaded successfully.
# Data for 2014-06-28 downloaded successfully.
# Downloading data:   5%|▍         | 181/3957 [00:34<11:07,  5.65it/s]
# Data for 2014-06-29 downloaded successfully.
# Data for 2014-06-30 downloaded successfully.
# Downloading data:   5%|▍         | 183/3957 [00:34<11:14,  5.60it/s]
# Data for 2014-07-01 downloaded successfully.
# Data for 2014-07-02 downloaded successfully.
# Downloading data:   5%|▍         | 185/3957 [00:34<11:10,  5.62it/s]
# Data for 2014-07-03 downloaded successfully.
# Data for 2014-07-04 downloaded successfully.
# Downloading data:   5%|▍         | 187/3957 [00:35<11:07,  5.65it/s]
# Data for 2014-07-05 downloaded successfully.
# Data for 2014-07-06 downloaded successfully.
# Downloading data:   5%|▍         | 189/3957 [00:35<10:55,  5.75it/s]
# Data for 2014-07-07 downloaded successfully.
# Data for 2014-07-08 downloaded successfully.
# Downloading data:   5%|▍         | 191/3957 [00:35<10:46,  5.83it/s]
# Data for 2014-07-09 downloaded successfully.
# Data for 2014-07-10 downloaded successfully.
# Downloading data:   5%|▍         | 193/3957 [00:36<11:00,  5.70it/s]
# Data for 2014-07-11 downloaded successfully.
# Data for 2014-07-12 downloaded successfully.
# Downloading data:   5%|▍         | 195/3957 [00:36<11:17,  5.55it/s]
# Data for 2014-07-13 downloaded successfully.
# Data for 2014-07-14 downloaded successfully.
# Downloading data:   5%|▍         | 197/3957 [00:36<11:14,  5.57it/s]
# Data for 2014-07-15 downloaded successfully.
# Data for 2014-07-16 downloaded successfully.
# Downloading data:   5%|▌         | 199/3957 [00:37<11:07,  5.63it/s]
# Data for 2014-07-17 downloaded successfully.
# Data for 2014-07-18 downloaded successfully.
# Downloading data:   5%|▌         | 201/3957 [00:37<11:04,  5.65it/s]
# Data for 2014-07-19 downloaded successfully.
# Data for 2014-07-20 downloaded successfully.
# Downloading data:   5%|▌         | 203/3957 [00:37<11:04,  5.65it/s]
# Data for 2014-07-21 downloaded successfully.
# Data for 2014-07-22 downloaded successfully.
# Downloading data:   5%|▌         | 205/3957 [00:38<11:07,  5.62it/s]
# Data for 2014-07-23 downloaded successfully.
# Data for 2014-07-24 downloaded successfully.
# Downloading data:   5%|▌         | 206/3957 [00:38<11:22,  5.50it/s]
# Data for 2014-07-25 downloaded successfully.
# Downloading data:   5%|▌         | 208/3957 [00:38<11:59,  5.21it/s]
# Data for 2014-07-26 downloaded successfully.
# Data for 2014-07-27 downloaded successfully.
# Downloading data:   5%|▌         | 210/3957 [00:39<11:50,  5.28it/s]
# Data for 2014-07-28 downloaded successfully.
# Data for 2014-07-29 downloaded successfully.
# Downloading data:   5%|▌         | 212/3957 [00:39<11:46,  5.30it/s]
# Data for 2014-07-30 downloaded successfully.
# Data for 2014-07-31 downloaded successfully.
# Downloading data:   5%|▌         | 214/3957 [00:39<11:15,  5.54it/s]
# Data for 2014-08-01 downloaded successfully.
# Data for 2014-08-02 downloaded successfully.
# Downloading data:   5%|▌         | 216/3957 [00:40<11:18,  5.51it/s]
# Data for 2014-08-03 downloaded successfully.
# Data for 2014-08-04 downloaded successfully.
# Downloading data:   5%|▌         | 217/3957 [00:40<11:20,  5.50it/s]
# Data for 2014-08-05 downloaded successfully.
# Data for 2014-08-06 downloaded successfully.
# Downloading data:   6%|▌         | 219/3957 [00:40<11:32,  5.40it/s]
# Data for 2014-08-07 downloaded successfully.
# Downloading data:   6%|▌         | 221/3957 [00:41<11:17,  5.52it/s]
# Data for 2014-08-08 downloaded successfully.
# Data for 2014-08-09 downloaded successfully.
# Downloading data:   6%|▌         | 223/3957 [00:41<11:13,  5.55it/s]
# Data for 2014-08-10 downloaded successfully.
# Data for 2014-08-11 downloaded successfully.
# Downloading data:   6%|▌         | 225/3957 [00:41<11:08,  5.58it/s]
# Data for 2014-08-12 downloaded successfully.
# Data for 2014-08-13 downloaded successfully.
# Downloading data:   6%|▌         | 227/3957 [00:42<11:15,  5.52it/s]
# Data for 2014-08-14 downloaded successfully.
# Data for 2014-08-15 downloaded successfully.
# Downloading data:   6%|▌         | 228/3957 [00:42<12:11,  5.09it/s]
# Data for 2014-08-16 downloaded successfully.
# Downloading data:   6%|▌         | 230/3957 [00:42<12:12,  5.09it/s]
# Data for 2014-08-17 downloaded successfully.
# Data for 2014-08-18 downloaded successfully.
# Downloading data:   6%|▌         | 232/3957 [00:43<11:42,  5.30it/s]
# Data for 2014-08-19 downloaded successfully.
# Data for 2014-08-20 downloaded successfully.
# Downloading data:   6%|▌         | 234/3957 [00:43<11:31,  5.38it/s]
# Data for 2014-08-21 downloaded successfully.
# Data for 2014-08-22 downloaded successfully.
# Downloading data:   6%|▌         | 235/3957 [00:43<11:31,  5.38it/s]
# Data for 2014-08-23 downloaded successfully.
# Downloading data:   6%|▌         | 237/3957 [00:44<11:46,  5.27it/s]
# Data for 2014-08-24 downloaded successfully.
# Data for 2014-08-25 downloaded successfully.
# Downloading data:   6%|▌         | 239/3957 [00:44<11:21,  5.46it/s]
# Data for 2014-08-26 downloaded successfully.
# Data for 2014-08-27 downloaded successfully.
# Downloading data:   6%|▌         | 241/3957 [00:44<11:07,  5.57it/s]
# Data for 2014-08-28 downloaded successfully.
# Data for 2014-08-29 downloaded successfully.
# Downloading data:   6%|▌         | 243/3957 [00:45<11:20,  5.46it/s]
# Data for 2014-08-30 downloaded successfully.
# Data for 2014-08-31 downloaded successfully.
# Downloading data:   6%|▌         | 245/3957 [00:45<11:22,  5.44it/s]
# Data for 2014-09-01 downloaded successfully.
# Data for 2014-09-02 downloaded successfully.
# Downloading data:   6%|▌         | 247/3957 [00:46<11:07,  5.55it/s]
# Data for 2014-09-03 downloaded successfully.
# Data for 2014-09-04 downloaded successfully.
# Downloading data:   6%|▋         | 249/3957 [00:46<11:14,  5.50it/s]
# Data for 2014-09-05 downloaded successfully.
# Data for 2014-09-06 downloaded successfully.
# Downloading data:   6%|▋         | 251/3957 [00:46<10:55,  5.66it/s]
# Data for 2014-09-07 downloaded successfully.
# Data for 2014-09-08 downloaded successfully.
# Downloading data:   6%|▋         | 253/3957 [00:47<10:43,  5.76it/s]
# Data for 2014-09-09 downloaded successfully.
# Data for 2014-09-10 downloaded successfully.
# Downloading data:   6%|▋         | 255/3957 [00:47<11:01,  5.60it/s]
# Data for 2014-09-11 downloaded successfully.
# Data for 2014-09-12 downloaded successfully.
# Downloading data:   6%|▋         | 257/3957 [00:47<10:49,  5.70it/s]
# Data for 2014-09-13 downloaded successfully.
# Data for 2014-09-14 downloaded successfully.
# Downloading data:   7%|▋         | 259/3957 [00:48<10:37,  5.80it/s]
# Data for 2014-09-15 downloaded successfully.
# Data for 2014-09-16 downloaded successfully.
# Downloading data:   7%|▋         | 261/3957 [00:48<10:25,  5.90it/s]
# Data for 2014-09-17 downloaded successfully.
# Data for 2014-09-18 downloaded successfully.
# Downloading data:   7%|▋         | 263/3957 [00:48<10:40,  5.77it/s]
# Data for 2014-09-19 downloaded successfully.
# Data for 2014-09-20 downloaded successfully.
# Downloading data:   7%|▋         | 265/3957 [00:49<10:35,  5.81it/s]
# Data for 2014-09-21 downloaded successfully.
# Data for 2014-09-22 downloaded successfully.
# Downloading data:   7%|▋         | 267/3957 [00:49<10:28,  5.88it/s]
# Data for 2014-09-23 downloaded successfully.
# Data for 2014-09-24 downloaded successfully.
# Downloading data:   7%|▋         | 269/3957 [00:49<10:36,  5.80it/s]
# Data for 2014-09-25 downloaded successfully.
# Data for 2014-09-26 downloaded successfully.
# Downloading data:   7%|▋         | 271/3957 [00:50<10:24,  5.90it/s]
# Data for 2014-09-27 downloaded successfully.
# Data for 2014-09-28 downloaded successfully.
# Downloading data:   7%|▋         | 273/3957 [00:50<10:22,  5.92it/s]
# Data for 2014-09-29 downloaded successfully.
# Data for 2014-09-30 downloaded successfully.
# Downloading data:   7%|▋         | 275/3957 [00:50<10:25,  5.89it/s]
# Data for 2014-10-01 downloaded successfully.
# Data for 2014-10-02 downloaded successfully.
# Downloading data:   7%|▋         | 277/3957 [00:51<10:24,  5.89it/s]
# Data for 2014-10-03 downloaded successfully.
# Data for 2014-10-04 downloaded successfully.
# Downloading data:   7%|▋         | 279/3957 [00:51<10:39,  5.75it/s]
# Data for 2014-10-05 downloaded successfully.
# Data for 2014-10-06 downloaded successfully.
# Downloading data:   7%|▋         | 281/3957 [00:51<10:29,  5.84it/s]
# Data for 2014-10-07 downloaded successfully.
# Data for 2014-10-08 downloaded successfully.
# Downloading data:   7%|▋         | 283/3957 [00:52<10:27,  5.86it/s]
# Data for 2014-10-09 downloaded successfully.
# Data for 2014-10-10 downloaded successfully.
# Downloading data:   7%|▋         | 284/3957 [00:52<10:27,  5.85it/s]
# Data for 2014-10-11 downloaded successfully.
# Downloading data:   7%|▋         | 286/3957 [00:52<10:59,  5.56it/s]
# Data for 2014-10-12 downloaded successfully.
# Data for 2014-10-13 downloaded successfully.
# Downloading data:   7%|▋         | 288/3957 [00:53<10:40,  5.73it/s]
# Data for 2014-10-14 downloaded successfully.
# Data for 2014-10-15 downloaded successfully.
# Downloading data:   7%|▋         | 290/3957 [00:53<10:49,  5.65it/s]
# Data for 2014-10-16 downloaded successfully.
# Data for 2014-10-17 downloaded successfully.
# Downloading data:   7%|▋         | 292/3957 [00:53<10:42,  5.70it/s]
# Data for 2014-10-18 downloaded successfully.
# Data for 2014-10-19 downloaded successfully.
# Downloading data:   7%|▋         | 294/3957 [00:54<10:36,  5.76it/s]
# Data for 2014-10-20 downloaded successfully.
# Data for 2014-10-21 downloaded successfully.
# Downloading data:   7%|▋         | 295/3957 [00:54<10:39,  5.72it/s]
# Data for 2014-10-22 downloaded successfully.
# Data for 2014-10-23 downloaded successfully.
# Downloading data:   8%|▊         | 297/3957 [00:54<11:17,  5.40it/s]
# Data for 2014-10-24 downloaded successfully.
# Downloading data:   8%|▊         | 299/3957 [00:55<11:03,  5.51it/s]
# Data for 2014-10-25 downloaded successfully.
# Data for 2014-10-26 downloaded successfully.
# Downloading data:   8%|▊         | 301/3957 [00:55<10:58,  5.55it/s]
# Data for 2014-10-27 downloaded successfully.
# Data for 2014-10-28 downloaded successfully.
# Downloading data:   8%|▊         | 303/3957 [00:55<10:50,  5.62it/s]
# Data for 2014-10-29 downloaded successfully.
# Data for 2014-10-30 downloaded successfully.
# Downloading data:   8%|▊         | 305/3957 [00:56<10:40,  5.70it/s]
# Data for 2014-10-31 downloaded successfully.
# Data for 2014-11-01 downloaded successfully.
# Downloading data:   8%|▊         | 307/3957 [00:56<10:32,  5.77it/s]
# Data for 2014-11-02 downloaded successfully.
# Data for 2014-11-03 downloaded successfully.
# Downloading data:   8%|▊         | 309/3957 [00:56<10:44,  5.66it/s]
# Data for 2014-11-04 downloaded successfully.
# Data for 2014-11-05 downloaded successfully.
# Downloading data:   8%|▊         | 311/3957 [00:57<10:59,  5.53it/s]
# Data for 2014-11-06 downloaded successfully.
# Data for 2014-11-07 downloaded successfully.
# Downloading data:   8%|▊         | 313/3957 [00:57<10:42,  5.68it/s]
# Data for 2014-11-08 downloaded successfully.
# Data for 2014-11-09 downloaded successfully.
# Downloading data:   8%|▊         | 315/3957 [00:57<10:25,  5.82it/s]
# Data for 2014-11-10 downloaded successfully.
# Data for 2014-11-11 downloaded successfully.
# Downloading data:   8%|▊         | 317/3957 [00:58<10:15,  5.91it/s]
# Data for 2014-11-12 downloaded successfully.
# Data for 2014-11-13 downloaded successfully.
# Downloading data:   8%|▊         | 319/3957 [00:58<10:08,  5.98it/s]
# Data for 2014-11-14 downloaded successfully.
# Data for 2014-11-15 downloaded successfully.
# Downloading data:   8%|▊         | 321/3957 [00:59<10:31,  5.75it/s]
# Data for 2014-11-16 downloaded successfully.
# Data for 2014-11-17 downloaded successfully.
# Downloading data:   8%|▊         | 323/3957 [00:59<10:35,  5.72it/s]
# Data for 2014-11-18 downloaded successfully.
# Data for 2014-11-19 downloaded successfully.
# Downloading data:   8%|▊         | 325/3957 [00:59<10:18,  5.87it/s]
# Data for 2014-11-20 downloaded successfully.
# Data for 2014-11-21 downloaded successfully.
# Downloading data:   8%|▊         | 327/3957 [01:00<10:33,  5.73it/s]
# Data for 2014-11-22 downloaded successfully.
# Data for 2014-11-23 downloaded successfully.
# Downloading data:   8%|▊         | 329/3957 [01:00<10:13,  5.91it/s]
# Data for 2014-11-24 downloaded successfully.
# Data for 2014-11-25 downloaded successfully.
# Downloading data:   8%|▊         | 331/3957 [01:00<10:10,  5.94it/s]
# Data for 2014-11-26 downloaded successfully.
# Data for 2014-11-27 downloaded successfully.
# Downloading data:   8%|▊         | 333/3957 [01:01<10:00,  6.03it/s]
# Data for 2014-11-28 downloaded successfully.
# Data for 2014-11-29 downloaded successfully.
# Downloading data:   8%|▊         | 335/3957 [01:01<10:06,  5.98it/s]
# Data for 2014-11-30 downloaded successfully.
# Data for 2014-12-01 downloaded successfully.
# Downloading data:   9%|▊         | 337/3957 [01:01<10:16,  5.87it/s]
# Data for 2014-12-02 downloaded successfully.
# Data for 2014-12-03 downloaded successfully.
# Downloading data:   9%|▊         | 339/3957 [01:02<10:09,  5.94it/s]
# Data for 2014-12-04 downloaded successfully.
# Data for 2014-12-05 downloaded successfully.
# Downloading data:   9%|▊         | 341/3957 [01:02<10:00,  6.02it/s]
# Data for 2014-12-06 downloaded successfully.
# Data for 2014-12-07 downloaded successfully.
# Downloading data:   9%|▊         | 343/3957 [01:02<09:57,  6.05it/s]
# Data for 2014-12-08 downloaded successfully.
# Data for 2014-12-09 downloaded successfully.
# Downloading data:   9%|▊         | 345/3957 [01:03<09:58,  6.04it/s]
# Data for 2014-12-10 downloaded successfully.
# Data for 2014-12-11 downloaded successfully.
# Downloading data:   9%|▉         | 347/3957 [01:03<09:59,  6.03it/s]
# Data for 2014-12-12 downloaded successfully.
# Data for 2014-12-13 downloaded successfully.
# Downloading data:   9%|▉         | 349/3957 [01:03<10:03,  5.98it/s]
# Data for 2014-12-14 downloaded successfully.
# Data for 2014-12-15 downloaded successfully.
# Downloading data:   9%|▉         | 351/3957 [01:04<10:10,  5.90it/s]
# Data for 2014-12-16 downloaded successfully.
# Data for 2014-12-17 downloaded successfully.
# Downloading data:   9%|▉         | 353/3957 [01:04<09:58,  6.02it/s]
# Data for 2014-12-18 downloaded successfully.
# Data for 2014-12-19 downloaded successfully.
# Downloading data:   9%|▉         | 355/3957 [01:04<10:01,  5.99it/s]
# Data for 2014-12-20 downloaded successfully.
# Data for 2014-12-21 downloaded successfully.
# Downloading data:   9%|▉         | 357/3957 [01:05<10:04,  5.96it/s]
# Data for 2014-12-22 downloaded successfully.
# Data for 2014-12-23 downloaded successfully.
# Downloading data:   9%|▉         | 359/3957 [01:05<10:00,  6.00it/s]
# Data for 2014-12-24 downloaded successfully.
# Data for 2014-12-25 downloaded successfully.
# Downloading data:   9%|▉         | 361/3957 [01:05<09:56,  6.03it/s]
# Data for 2014-12-26 downloaded successfully.
# Data for 2014-12-27 downloaded successfully.
# Downloading data:   9%|▉         | 363/3957 [01:06<09:57,  6.01it/s]
# Data for 2014-12-28 downloaded successfully.
# Data for 2014-12-29 downloaded successfully.
# Downloading data:   9%|▉         | 365/3957 [01:06<10:01,  5.98it/s]
# Data for 2014-12-30 downloaded successfully.
# Data for 2014-12-31 downloaded successfully.
# Downloading data:   9%|▉         | 367/3957 [01:06<10:07,  5.91it/s]
# Data for 2015-01-01 downloaded successfully.
# Data for 2015-01-02 downloaded successfully.
# Downloading data:   9%|▉         | 369/3957 [01:07<10:11,  5.87it/s]
# Data for 2015-01-03 downloaded successfully.
# Data for 2015-01-04 downloaded successfully.
# Downloading data:   9%|▉         | 371/3957 [01:07<10:11,  5.87it/s]
# Data for 2015-01-05 downloaded successfully.
# Data for 2015-01-06 downloaded successfully.
# Downloading data:   9%|▉         | 373/3957 [01:07<10:27,  5.71it/s]
# Data for 2015-01-07 downloaded successfully.
# Data for 2015-01-08 downloaded successfully.
# Downloading data:   9%|▉         | 375/3957 [01:08<10:18,  5.79it/s]
# Data for 2015-01-09 downloaded successfully.
# Data for 2015-01-10 downloaded successfully.
# Downloading data:  10%|▉         | 377/3957 [01:08<10:07,  5.89it/s]
# Data for 2015-01-11 downloaded successfully.
# Data for 2015-01-12 downloaded successfully.
# Downloading data:  10%|▉         | 379/3957 [01:08<10:09,  5.87it/s]
# Data for 2015-01-13 downloaded successfully.
# Data for 2015-01-14 downloaded successfully.
# Downloading data:  10%|▉         | 381/3957 [01:09<09:55,  6.00it/s]
# Data for 2015-01-15 downloaded successfully.
# Data for 2015-01-16 downloaded successfully.
# Downloading data:  10%|▉         | 383/3957 [01:09<09:55,  6.00it/s]
# Data for 2015-01-17 downloaded successfully.
# Data for 2015-01-18 downloaded successfully.
# Downloading data:  10%|▉         | 385/3957 [01:09<09:52,  6.02it/s]
# Data for 2015-01-19 downloaded successfully.
# Data for 2015-01-20 downloaded successfully.
# Downloading data:  10%|▉         | 387/3957 [01:10<09:49,  6.05it/s]
# Data for 2015-01-21 downloaded successfully.
# Data for 2015-01-22 downloaded successfully.
# Downloading data:  10%|▉         | 389/3957 [01:10<10:21,  5.74it/s]
# Data for 2015-01-23 downloaded successfully.
# Data for 2015-01-24 downloaded successfully.
# Downloading data:  10%|▉         | 391/3957 [01:10<10:14,  5.80it/s]
# Data for 2015-01-25 downloaded successfully.
# Data for 2015-01-26 downloaded successfully.
# Downloading data:  10%|▉         | 393/3957 [01:11<09:57,  5.97it/s]
# Data for 2015-01-27 downloaded successfully.
# Data for 2015-01-28 downloaded successfully.
# Downloading data:  10%|▉         | 395/3957 [01:11<09:52,  6.01it/s]
# Data for 2015-01-29 downloaded successfully.
# Data for 2015-01-30 downloaded successfully.
# Downloading data:  10%|█         | 397/3957 [01:11<09:50,  6.03it/s]
# Data for 2015-01-31 downloaded successfully.
# Data for 2015-02-01 downloaded successfully.
# Downloading data:  10%|█         | 399/3957 [01:12<10:09,  5.84it/s]
# Data for 2015-02-02 downloaded successfully.
# Data for 2015-02-03 downloaded successfully.
# Downloading data:  10%|█         | 401/3957 [01:12<10:01,  5.92it/s]
# Data for 2015-02-04 downloaded successfully.
# Data for 2015-02-05 downloaded successfully.
# Downloading data:  10%|█         | 403/3957 [01:12<09:55,  5.97it/s]
# Data for 2015-02-06 downloaded successfully.
# Data for 2015-02-07 downloaded successfully.
# Downloading data:  10%|█         | 405/3957 [01:13<09:51,  6.00it/s]
# Data for 2015-02-08 downloaded successfully.
# Data for 2015-02-09 downloaded successfully.
# Downloading data:  10%|█         | 407/3957 [01:13<09:46,  6.06it/s]
# Data for 2015-02-10 downloaded successfully.
# Data for 2015-02-11 downloaded successfully.
# Downloading data:  10%|█         | 409/3957 [01:13<09:43,  6.08it/s]
# Data for 2015-02-12 downloaded successfully.
# Data for 2015-02-13 downloaded successfully.
# Downloading data:  10%|█         | 411/3957 [01:14<10:09,  5.81it/s]
# Data for 2015-02-14 downloaded successfully.
# Data for 2015-02-15 downloaded successfully.
# Downloading data:  10%|█         | 413/3957 [01:14<10:04,  5.87it/s]
# Data for 2015-02-16 downloaded successfully.
# Data for 2015-02-17 downloaded successfully.
# Downloading data:  10%|█         | 415/3957 [01:14<10:00,  5.90it/s]
# Data for 2015-02-18 downloaded successfully.
# Data for 2015-02-19 downloaded successfully.
# Downloading data:  11%|█         | 417/3957 [01:15<09:57,  5.93it/s]
# Data for 2015-02-20 downloaded successfully.
# Data for 2015-02-21 downloaded successfully.
# Downloading data:  11%|█         | 419/3957 [01:15<09:52,  5.97it/s]
# Data for 2015-02-22 downloaded successfully.
# Data for 2015-02-23 downloaded successfully.
# Downloading data:  11%|█         | 421/3957 [01:15<09:47,  6.01it/s]
# Data for 2015-02-24 downloaded successfully.
# Data for 2015-02-25 downloaded successfully.
# Downloading data:  11%|█         | 423/3957 [01:16<10:10,  5.79it/s]
# Data for 2015-02-26 downloaded successfully.
# Data for 2015-02-27 downloaded successfully.
# Downloading data:  11%|█         | 425/3957 [01:16<09:57,  5.91it/s]
# Data for 2015-02-28 downloaded successfully.
# Data for 2015-03-01 downloaded successfully.
# Downloading data:  11%|█         | 426/3957 [01:16<09:57,  5.91it/s]
# Data for 2015-03-02 downloaded successfully.
# Downloading data:  11%|█         | 429/3957 [01:17<10:04,  5.84it/s]
# Data for 2015-03-03 downloaded successfully.
# Data for 2015-03-04 downloaded successfully.
# Data for 2015-03-05 downloaded successfully.
# Downloading data:  11%|█         | 431/3957 [01:17<10:01,  5.87it/s]
# Data for 2015-03-06 downloaded successfully.
# Data for 2015-03-07 downloaded successfully.
# Downloading data:  11%|█         | 433/3957 [01:17<09:48,  5.99it/s]
# Data for 2015-03-08 downloaded successfully.
# Data for 2015-03-09 downloaded successfully.
# Downloading data:  11%|█         | 435/3957 [01:18<09:55,  5.92it/s]
# Data for 2015-03-10 downloaded successfully.
# Data for 2015-03-11 downloaded successfully.
# Downloading data:  11%|█         | 437/3957 [01:18<10:08,  5.78it/s]
# Data for 2015-03-12 downloaded successfully.
# Data for 2015-03-13 downloaded successfully.
# Downloading data:  11%|█         | 439/3957 [01:18<10:36,  5.53it/s]
# Data for 2015-03-14 downloaded successfully.
# Data for 2015-03-15 downloaded successfully.
# Downloading data:  11%|█         | 441/3957 [01:19<10:29,  5.59it/s]
# Data for 2015-03-16 downloaded successfully.
# Data for 2015-03-17 downloaded successfully.
# Downloading data:  11%|█         | 443/3957 [01:19<10:19,  5.67it/s]
# Data for 2015-03-18 downloaded successfully.
# Data for 2015-03-19 downloaded successfully.
# Downloading data:  11%|█         | 445/3957 [01:20<10:10,  5.75it/s]
# Data for 2015-03-20 downloaded successfully.
# Data for 2015-03-21 downloaded successfully.
# Downloading data:  11%|█▏        | 447/3957 [01:20<10:00,  5.85it/s]
# Data for 2015-03-22 downloaded successfully.
# Data for 2015-03-23 downloaded successfully.
# Downloading data:  11%|█▏        | 449/3957 [01:20<09:57,  5.87it/s]
# Data for 2015-03-24 downloaded successfully.
# Data for 2015-03-25 downloaded successfully.
# Downloading data:  11%|█▏        | 451/3957 [01:21<09:47,  5.96it/s]
# Data for 2015-03-26 downloaded successfully.
# Data for 2015-03-27 downloaded successfully.
# Downloading data:  11%|█▏        | 453/3957 [01:21<09:47,  5.96it/s]
# Data for 2015-03-28 downloaded successfully.
# Data for 2015-03-29 downloaded successfully.
# Downloading data:  11%|█▏        | 455/3957 [01:21<09:47,  5.96it/s]
# Data for 2015-03-30 downloaded successfully.
# Data for 2015-03-31 downloaded successfully.
# Downloading data:  12%|█▏        | 457/3957 [01:22<09:44,  5.99it/s]
# Data for 2015-04-01 downloaded successfully.
# Data for 2015-04-02 downloaded successfully.
# Downloading data:  12%|█▏        | 459/3957 [01:22<09:46,  5.96it/s]
# Data for 2015-04-03 downloaded successfully.
# Data for 2015-04-04 downloaded successfully.
# Downloading data:  12%|█▏        | 461/3957 [01:22<10:13,  5.70it/s]
# Data for 2015-04-05 downloaded successfully.
# Data for 2015-04-06 downloaded successfully.
# Downloading data:  12%|█▏        | 463/3957 [01:23<09:58,  5.84it/s]
# Data for 2015-04-07 downloaded successfully.
# Data for 2015-04-08 downloaded successfully.
# Downloading data:  12%|█▏        | 465/3957 [01:23<09:45,  5.96it/s]
# Data for 2015-04-09 downloaded successfully.
# Data for 2015-04-10 downloaded successfully.
# Downloading data:  12%|█▏        | 467/3957 [01:23<09:40,  6.01it/s]
# Data for 2015-04-11 downloaded successfully.
# Data for 2015-04-12 downloaded successfully.
# Downloading data:  12%|█▏        | 469/3957 [01:24<09:37,  6.04it/s]
# Data for 2015-04-13 downloaded successfully.
# Data for 2015-04-14 downloaded successfully.
# Downloading data:  12%|█▏        | 471/3957 [01:24<09:56,  5.85it/s]
# Data for 2015-04-15 downloaded successfully.
# Data for 2015-04-16 downloaded successfully.
# Downloading data:  12%|█▏        | 473/3957 [01:24<09:45,  5.95it/s]
# Data for 2015-04-17 downloaded successfully.
# Data for 2015-04-18 downloaded successfully.
# Downloading data:  12%|█▏        | 474/3957 [01:24<09:41,  5.99it/s]
# Data for 2015-04-19 downloaded successfully.
# Downloading data:  12%|█▏        | 476/3957 [01:25<10:16,  5.65it/s]
# Data for 2015-04-20 downloaded successfully.
# Data for 2015-04-21 downloaded successfully.
# Downloading data:  12%|█▏        | 478/3957 [01:25<09:54,  5.85it/s]
# Data for 2015-04-22 downloaded successfully.
# Data for 2015-04-23 downloaded successfully.
# Downloading data:  12%|█▏        | 480/3957 [01:25<09:49,  5.90it/s]
# Data for 2015-04-24 downloaded successfully.
# Data for 2015-04-25 downloaded successfully.
# Downloading data:  12%|█▏        | 482/3957 [01:26<09:42,  5.97it/s]
# Data for 2015-04-26 downloaded successfully.
# Data for 2015-04-27 downloaded successfully.
# Downloading data:  12%|█▏        | 484/3957 [01:26<09:36,  6.03it/s]
# Data for 2015-04-28 downloaded successfully.
# Data for 2015-04-29 downloaded successfully.
# Downloading data:  12%|█▏        | 486/3957 [01:26<09:35,  6.03it/s]
# Data for 2015-04-30 downloaded successfully.
# Data for 2015-05-01 downloaded successfully.
# Downloading data:  12%|█▏        | 488/3957 [01:27<09:35,  6.03it/s]
# Data for 2015-05-02 downloaded successfully.
# Data for 2015-05-03 downloaded successfully.
# Downloading data:  12%|█▏        | 490/3957 [01:27<09:34,  6.04it/s]
# Data for 2015-05-04 downloaded successfully.
# Data for 2015-05-05 downloaded successfully.
# Downloading data:  12%|█▏        | 492/3957 [01:27<09:42,  5.95it/s]
# Data for 2015-05-06 downloaded successfully.
# Data for 2015-05-07 downloaded successfully.
# Downloading data:  12%|█▏        | 494/3957 [01:28<09:42,  5.95it/s]
# Data for 2015-05-08 downloaded successfully.
# Data for 2015-05-09 downloaded successfully.
# Downloading data:  13%|█▎        | 496/3957 [01:28<09:38,  5.98it/s]
# Data for 2015-05-10 downloaded successfully.
# Data for 2015-05-11 downloaded successfully.
# Downloading data:  13%|█▎        | 498/3957 [01:28<09:47,  5.89it/s]
# Data for 2015-05-12 downloaded successfully.
# Data for 2015-05-13 downloaded successfully.
# Downloading data:  13%|█▎        | 500/3957 [01:29<09:46,  5.89it/s]
# Data for 2015-05-14 downloaded successfully.
# Data for 2015-05-15 downloaded successfully.
# Downloading data:  13%|█▎        | 502/3957 [01:29<09:46,  5.89it/s]
# Data for 2015-05-16 downloaded successfully.
# Data for 2015-05-17 downloaded successfully.
# Downloading data:  13%|█▎        | 504/3957 [01:29<09:46,  5.89it/s]
# Data for 2015-05-18 downloaded successfully.
# Data for 2015-05-19 downloaded successfully.
# Downloading data:  13%|█▎        | 506/3957 [01:30<10:15,  5.61it/s]
# Data for 2015-05-20 downloaded successfully.
# Data for 2015-05-21 downloaded successfully.
# Downloading data:  13%|█▎        | 508/3957 [01:30<10:21,  5.55it/s]
# Data for 2015-05-22 downloaded successfully.
# Data for 2015-05-23 downloaded successfully.
# Downloading data:  13%|█▎        | 510/3957 [01:31<10:16,  5.60it/s]
# Data for 2015-05-24 downloaded successfully.
# Data for 2015-05-25 downloaded successfully.
# Downloading data:  13%|█▎        | 512/3957 [01:31<10:13,  5.62it/s]
# Data for 2015-05-26 downloaded successfully.
# Data for 2015-05-27 downloaded successfully.
# Downloading data:  13%|█▎        | 514/3957 [01:31<10:22,  5.53it/s]
# Data for 2015-05-28 downloaded successfully.
# Data for 2015-05-29 downloaded successfully.
# Downloading data:  13%|█▎        | 516/3957 [01:32<10:04,  5.69it/s]
# Data for 2015-05-30 downloaded successfully.
# Data for 2015-05-31 downloaded successfully.
# Downloading data:  13%|█▎        | 518/3957 [01:32<09:48,  5.84it/s]
# Data for 2015-06-01 downloaded successfully.
# Data for 2015-06-02 downloaded successfully.
# Downloading data:  13%|█▎        | 520/3957 [01:32<09:43,  5.89it/s]
# Data for 2015-06-03 downloaded successfully.
# Data for 2015-06-04 downloaded successfully.
# Downloading data:  13%|█▎        | 522/3957 [01:33<09:38,  5.94it/s]
# Data for 2015-06-05 downloaded successfully.
# Data for 2015-06-06 downloaded successfully.
# Downloading data:  13%|█▎        | 524/3957 [01:33<09:33,  5.98it/s]
# Data for 2015-06-07 downloaded successfully.
# Data for 2015-06-08 downloaded successfully.
# Downloading data:  13%|█▎        | 526/3957 [01:33<09:30,  6.01it/s]
# Data for 2015-06-09 downloaded successfully.
# Data for 2015-06-10 downloaded successfully.
# Downloading data:  13%|█▎        | 528/3957 [01:34<09:26,  6.05it/s]
# Data for 2015-06-11 downloaded successfully.
# Data for 2015-06-12 downloaded successfully.
# Downloading data:  13%|█▎        | 530/3957 [01:34<09:28,  6.02it/s]
# Data for 2015-06-13 downloaded successfully.
# Data for 2015-06-14 downloaded successfully.
# Downloading data:  13%|█▎        | 532/3957 [01:34<09:26,  6.05it/s]
# Data for 2015-06-15 downloaded successfully.
# Data for 2015-06-16 downloaded successfully.
# Downloading data:  13%|█▎        | 534/3957 [01:35<09:27,  6.03it/s]
# Data for 2015-06-17 downloaded successfully.
# Data for 2015-06-18 downloaded successfully.
# Downloading data:  14%|█▎        | 536/3957 [01:35<09:31,  5.99it/s]
# Data for 2015-06-19 downloaded successfully.
# Data for 2015-06-20 downloaded successfully.
# Downloading data:  14%|█▎        | 538/3957 [01:35<09:29,  6.01it/s]
# Data for 2015-06-21 downloaded successfully.
# Data for 2015-06-22 downloaded successfully.
# Downloading data:  14%|█▎        | 540/3957 [01:36<09:26,  6.03it/s]
# Data for 2015-06-23 downloaded successfully.
# Data for 2015-06-24 downloaded successfully.
# Downloading data:  14%|█▎        | 542/3957 [01:36<09:29,  5.99it/s]
# Data for 2015-06-25 downloaded successfully.
# Data for 2015-06-26 downloaded successfully.
# Downloading data:  14%|█▎        | 544/3957 [01:36<09:46,  5.82it/s]
# Data for 2015-06-27 downloaded successfully.
# Data for 2015-06-28 downloaded successfully.
# Downloading data:  14%|█▍        | 546/3957 [01:37<09:44,  5.83it/s]
# Data for 2015-06-29 downloaded successfully.
# Data for 2015-06-30 downloaded successfully.
# Downloading data:  14%|█▍        | 548/3957 [01:37<09:33,  5.95it/s]
# Data for 2015-07-01 downloaded successfully.
# Data for 2015-07-02 downloaded successfully.
# Downloading data:  14%|█▍        | 550/3957 [01:37<09:30,  5.97it/s]
# Data for 2015-07-03 downloaded successfully.
# Data for 2015-07-04 downloaded successfully.
# Downloading data:  14%|█▍        | 552/3957 [01:38<09:24,  6.03it/s]
# Data for 2015-07-05 downloaded successfully.
# Data for 2015-07-06 downloaded successfully.
# Downloading data:  14%|█▍        | 554/3957 [01:38<09:37,  5.89it/s]
# Data for 2015-07-07 downloaded successfully.
# Data for 2015-07-08 downloaded successfully.
# Downloading data:  14%|█▍        | 556/3957 [01:38<09:28,  5.99it/s]
# Data for 2015-07-09 downloaded successfully.
# Data for 2015-07-10 downloaded successfully.
# Downloading data:  14%|█▍        | 558/3957 [01:39<09:21,  6.05it/s]
# Data for 2015-07-11 downloaded successfully.
# Data for 2015-07-12 downloaded successfully.
# Downloading data:  14%|█▍        | 560/3957 [01:39<09:19,  6.07it/s]
# Data for 2015-07-13 downloaded successfully.
# Data for 2015-07-14 downloaded successfully.
# Downloading data:  14%|█▍        | 562/3957 [01:39<09:20,  6.06it/s]
# Data for 2015-07-15 downloaded successfully.
# Data for 2015-07-16 downloaded successfully.
# Downloading data:  14%|█▍        | 564/3957 [01:40<09:27,  5.98it/s]
# Data for 2015-07-17 downloaded successfully.
# Data for 2015-07-18 downloaded successfully.
# Downloading data:  14%|█▍        | 566/3957 [01:40<09:30,  5.94it/s]
# Data for 2015-07-19 downloaded successfully.
# Data for 2015-07-20 downloaded successfully.
# Downloading data:  14%|█▍        | 568/3957 [01:40<09:23,  6.01it/s]
# Data for 2015-07-21 downloaded successfully.
# Data for 2015-07-22 downloaded successfully.
# Downloading data:  14%|█▍        | 570/3957 [01:41<09:20,  6.04it/s]
# Data for 2015-07-23 downloaded successfully.
# Data for 2015-07-24 downloaded successfully.
# Downloading data:  14%|█▍        | 572/3957 [01:41<09:37,  5.86it/s]
# Data for 2015-07-25 downloaded successfully.
# Data for 2015-07-26 downloaded successfully.
# Downloading data:  15%|█▍        | 574/3957 [01:41<09:25,  5.98it/s]
# Data for 2015-07-27 downloaded successfully.
# Data for 2015-07-28 downloaded successfully.
# Downloading data:  15%|█▍        | 576/3957 [01:42<09:53,  5.70it/s]
# Data for 2015-07-29 downloaded successfully.
# Data for 2015-07-30 downloaded successfully.
# Downloading data:  15%|█▍        | 577/3957 [01:42<09:57,  5.65it/s]
# Data for 2015-07-31 downloaded successfully.
# Downloading data:  15%|█▍        | 579/3957 [01:42<10:18,  5.46it/s]
# Data for 2015-08-01 downloaded successfully.
# Data for 2015-08-02 downloaded successfully.
# Downloading data:  15%|█▍        | 581/3957 [01:43<10:04,  5.59it/s]
# Data for 2015-08-03 downloaded successfully.
# Data for 2015-08-04 downloaded successfully.
# Downloading data:  15%|█▍        | 583/3957 [01:43<09:55,  5.67it/s]
# Data for 2015-08-05 downloaded successfully.
# Data for 2015-08-06 downloaded successfully.
# Downloading data:  15%|█▍        | 585/3957 [01:43<09:48,  5.73it/s]
# Data for 2015-08-07 downloaded successfully.
# Data for 2015-08-08 downloaded successfully.
# Downloading data:  15%|█▍        | 586/3957 [01:43<09:44,  5.77it/s]
# Data for 2015-08-09 downloaded successfully.
# Downloading data:  15%|█▍        | 588/3957 [01:44<10:33,  5.32it/s]
# Data for 2015-08-10 downloaded successfully.
# Data for 2015-08-11 downloaded successfully.
# Downloading data:  15%|█▍        | 590/3957 [01:44<09:52,  5.68it/s]
# Data for 2015-08-12 downloaded successfully.
# Data for 2015-08-13 downloaded successfully.
# Downloading data:  15%|█▍        | 592/3957 [01:45<09:39,  5.81it/s]
# Data for 2015-08-14 downloaded successfully.
# ...
# Data for 2024-04-16 downloaded successfully.
# Data for 2024-04-17 downloaded successfully.
# Downloading data:  95%|█████████▌| 3762/3957 [10:45<00:33,  5.89it/s]
# Data for 2024-04-18 downloaded successfully.
# Data for 2024-04-19 downloaded successfully.
# Downloading data:  95%|█████████▌| 3764/3957 [10:45<00:31,  6.05it/s]
# Data for 2024-04-20 downloaded successfully.
# Data for 2024-04-21 downloaded successfully.
# Downloading data:  95%|█████████▌| 3766/3957 [10:46<00:31,  6.08it/s]
# Data for 2024-04-22 downloaded successfully.
# Data for 2024-04-23 downloaded successfully.
# Downloading data:  95%|█████████▌| 3768/3957 [10:46<00:31,  6.05it/s]
# Data for 2024-04-24 downloaded successfully.
# Data for 2024-04-25 downloaded successfully.
# Downloading data:  95%|█████████▌| 3770/3957 [10:46<00:30,  6.15it/s]
# Data for 2024-04-26 downloaded successfully.
# Data for 2024-04-27 downloaded successfully.
# Downloading data:  95%|█████████▌| 3772/3957 [10:47<00:29,  6.21it/s]
# Data for 2024-04-28 downloaded successfully.
# Data for 2024-04-29 downloaded successfully.
# Downloading data:  95%|█████████▌| 3774/3957 [10:47<00:29,  6.18it/s]
# Data for 2024-04-30 downloaded successfully.
# Data for 2024-05-01 downloaded successfully.
# Downloading data:  95%|█████████▌| 3776/3957 [10:47<00:29,  6.12it/s]
# Data for 2024-05-02 downloaded successfully.
# Data for 2024-05-03 downloaded successfully.
# Downloading data:  95%|█████████▌| 3778/3957 [10:47<00:28,  6.18it/s]
# Data for 2024-05-04 downloaded successfully.
# Data for 2024-05-05 downloaded successfully.
# Downloading data:  96%|█████████▌| 3780/3957 [10:48<00:28,  6.16it/s]
# Data for 2024-05-06 downloaded successfully.
# Data for 2024-05-07 downloaded successfully.
# Downloading data:  96%|█████████▌| 3782/3957 [10:48<00:29,  5.99it/s]
# Data for 2024-05-08 downloaded successfully.
# Data for 2024-05-09 downloaded successfully.
# Downloading data:  96%|█████████▌| 3784/3957 [10:49<00:30,  5.65it/s]
# Data for 2024-05-10 downloaded successfully.
# Data for 2024-05-11 downloaded successfully.
# Downloading data:  96%|█████████▌| 3786/3957 [10:49<00:28,  5.90it/s]
# Data for 2024-05-12 downloaded successfully.
# Data for 2024-05-13 downloaded successfully.
# Downloading data:  96%|█████████▌| 3788/3957 [10:49<00:27,  6.05it/s]
# Data for 2024-05-14 downloaded successfully.
# Data for 2024-05-15 downloaded successfully.
# Downloading data:  96%|█████████▌| 3790/3957 [10:49<00:27,  6.17it/s]
# Data for 2024-05-16 downloaded successfully.
# Data for 2024-05-17 downloaded successfully.
# Downloading data:  96%|█████████▌| 3792/3957 [10:50<00:26,  6.19it/s]
# Data for 2024-05-18 downloaded successfully.
# Data for 2024-05-19 downloaded successfully.
# Downloading data:  96%|█████████▌| 3794/3957 [10:50<00:26,  6.23it/s]
# Data for 2024-05-20 downloaded successfully.
# Data for 2024-05-21 downloaded successfully.
# Downloading data:  96%|█████████▌| 3796/3957 [10:50<00:25,  6.22it/s]
# Data for 2024-05-22 downloaded successfully.
# Data for 2024-05-23 downloaded successfully.
# Downloading data:  96%|█████████▌| 3798/3957 [10:51<00:25,  6.15it/s]
# Data for 2024-05-24 downloaded successfully.
# Data for 2024-05-25 downloaded successfully.
# Downloading data:  96%|█████████▌| 3800/3957 [10:51<00:25,  6.11it/s]
# Data for 2024-05-26 downloaded successfully.
# Data for 2024-05-27 downloaded successfully.
# Downloading data:  96%|█████████▌| 3802/3957 [10:51<00:25,  6.13it/s]
# Data for 2024-05-28 downloaded successfully.
# Data for 2024-05-29 downloaded successfully.
# Downloading data:  96%|█████████▌| 3804/3957 [10:52<00:24,  6.21it/s]
# Data for 2024-05-30 downloaded successfully.
# Data for 2024-05-31 downloaded successfully.
# Downloading data:  96%|█████████▌| 3806/3957 [10:52<00:24,  6.26it/s]
# Data for 2024-06-01 downloaded successfully.
# Data for 2024-06-02 downloaded successfully.
# Downloading data:  96%|█████████▌| 3808/3957 [10:52<00:23,  6.25it/s]
# Data for 2024-06-03 downloaded successfully.
# Data for 2024-06-04 downloaded successfully.
# Downloading data:  96%|█████████▋| 3810/3957 [10:53<00:23,  6.20it/s]
# Data for 2024-06-05 downloaded successfully.
# Data for 2024-06-06 downloaded successfully.
# Downloading data:  96%|█████████▋| 3812/3957 [10:53<00:24,  5.94it/s]
# Data for 2024-06-07 downloaded successfully.
# Data for 2024-06-08 downloaded successfully.
# Downloading data:  96%|█████████▋| 3814/3957 [10:53<00:23,  5.98it/s]
# Data for 2024-06-09 downloaded successfully.
# Data for 2024-06-10 downloaded successfully.
# Downloading data:  96%|█████████▋| 3816/3957 [10:54<00:23,  5.90it/s]
# Data for 2024-06-11 downloaded successfully.
# Data for 2024-06-12 downloaded successfully.
# Downloading data:  96%|█████████▋| 3818/3957 [10:54<00:23,  5.93it/s]
# Data for 2024-06-13 downloaded successfully.
# Data for 2024-06-14 downloaded successfully.
# Downloading data:  97%|█████████▋| 3820/3957 [10:54<00:23,  5.89it/s]
# Data for 2024-06-15 downloaded successfully.
# Data for 2024-06-16 downloaded successfully.
# Downloading data:  97%|█████████▋| 3822/3957 [10:55<00:22,  5.94it/s]
# Data for 2024-06-17 downloaded successfully.
# Data for 2024-06-18 downloaded successfully.
# Downloading data:  97%|█████████▋| 3824/3957 [10:55<00:22,  5.90it/s]
# Data for 2024-06-19 downloaded successfully.
# Data for 2024-06-20 downloaded successfully.
# Downloading data:  97%|█████████▋| 3826/3957 [10:55<00:21,  6.07it/s]
# Data for 2024-06-21 downloaded successfully.
# Data for 2024-06-22 downloaded successfully.
# Downloading data:  97%|█████████▋| 3828/3957 [10:56<00:21,  6.08it/s]
# Data for 2024-06-23 downloaded successfully.
# Data for 2024-06-24 downloaded successfully.
# Downloading data:  97%|█████████▋| 3830/3957 [10:56<00:20,  6.12it/s]
# Data for 2024-06-25 downloaded successfully.
# Data for 2024-06-26 downloaded successfully.
# Downloading data:  97%|█████████▋| 3832/3957 [10:56<00:20,  5.98it/s]
# Data for 2024-06-27 downloaded successfully.
# Data for 2024-06-28 downloaded successfully.
# Downloading data:  97%|█████████▋| 3834/3957 [10:57<00:20,  5.87it/s]
# Data for 2024-06-29 downloaded successfully.
# Data for 2024-06-30 downloaded successfully.
# Downloading data:  97%|█████████▋| 3836/3957 [10:57<00:20,  6.00it/s]
# Data for 2024-07-01 downloaded successfully.
# Data for 2024-07-02 downloaded successfully.
# Downloading data:  97%|█████████▋| 3838/3957 [10:57<00:19,  6.13it/s]
# Data for 2024-07-03 downloaded successfully.
# Data for 2024-07-04 downloaded successfully.
# Downloading data:  97%|█████████▋| 3840/3957 [10:58<00:18,  6.18it/s]
# Data for 2024-07-05 downloaded successfully.
# Data for 2024-07-06 downloaded successfully.
# Downloading data:  97%|█████████▋| 3842/3957 [10:58<00:18,  6.21it/s]
# Data for 2024-07-07 downloaded successfully.
# Data for 2024-07-08 downloaded successfully.
# Downloading data:  97%|█████████▋| 3844/3957 [10:58<00:18,  6.25it/s]
# Data for 2024-07-09 downloaded successfully.
# Data for 2024-07-10 downloaded successfully.
# Downloading data:  97%|█████████▋| 3846/3957 [10:59<00:17,  6.19it/s]
# Data for 2024-07-11 downloaded successfully.
# Data for 2024-07-12 downloaded successfully.
# Downloading data:  97%|█████████▋| 3848/3957 [10:59<00:17,  6.21it/s]
# Data for 2024-07-13 downloaded successfully.
# Data for 2024-07-14 downloaded successfully.
# Downloading data:  97%|█████████▋| 3850/3957 [10:59<00:17,  6.23it/s]
# Data for 2024-07-15 downloaded successfully.
# Data for 2024-07-16 downloaded successfully.
# Downloading data:  97%|█████████▋| 3852/3957 [11:00<00:16,  6.21it/s]
# Data for 2024-07-17 downloaded successfully.
# Data for 2024-07-18 downloaded successfully.
# Downloading data:  97%|█████████▋| 3854/3957 [11:00<00:16,  6.21it/s]
# Data for 2024-07-19 downloaded successfully.
# Data for 2024-07-20 downloaded successfully.
# Downloading data:  97%|█████████▋| 3856/3957 [11:00<00:16,  6.27it/s]
# Data for 2024-07-21 downloaded successfully.
# Data for 2024-07-22 downloaded successfully.
# Downloading data:  97%|█████████▋| 3858/3957 [11:01<00:15,  6.29it/s]
# Data for 2024-07-23 downloaded successfully.
# Data for 2024-07-24 downloaded successfully.
# Downloading data:  98%|█████████▊| 3860/3957 [11:01<00:15,  6.20it/s]
# Data for 2024-07-25 downloaded successfully.
# Data for 2024-07-26 downloaded successfully.
# Downloading data:  98%|█████████▊| 3862/3957 [11:01<00:15,  6.23it/s]
# Data for 2024-07-27 downloaded successfully.
# Data for 2024-07-28 downloaded successfully.
# Downloading data:  98%|█████████▊| 3864/3957 [11:02<00:15,  6.03it/s]
# Data for 2024-07-29 downloaded successfully.
# Data for 2024-07-30 downloaded successfully.
# Downloading data:  98%|█████████▊| 3866/3957 [11:02<00:14,  6.12it/s]
# Data for 2024-07-31 downloaded successfully.
# Data for 2024-08-01 downloaded successfully.
# Downloading data:  98%|█████████▊| 3868/3957 [11:02<00:14,  6.17it/s]
# Data for 2024-08-02 downloaded successfully.
# Data for 2024-08-03 downloaded successfully.
# Downloading data:  98%|█████████▊| 3870/3957 [11:03<00:13,  6.22it/s]
# Data for 2024-08-04 downloaded successfully.
# Data for 2024-08-05 downloaded successfully.
# Downloading data:  98%|█████████▊| 3872/3957 [11:03<00:13,  6.13it/s]
# Data for 2024-08-06 downloaded successfully.
# Data for 2024-08-07 downloaded successfully.
# Downloading data:  98%|█████████▊| 3874/3957 [11:03<00:13,  6.18it/s]
# Data for 2024-08-08 downloaded successfully.
# Data for 2024-08-09 downloaded successfully.
# Downloading data:  98%|█████████▊| 3876/3957 [11:04<00:13,  6.05it/s]
# Data for 2024-08-10 downloaded successfully.
# Data for 2024-08-11 downloaded successfully.
# Downloading data:  98%|█████████▊| 3878/3957 [11:04<00:12,  6.17it/s]
# Data for 2024-08-12 downloaded successfully.
# Data for 2024-08-13 downloaded successfully.
# Downloading data:  98%|█████████▊| 3880/3957 [11:04<00:12,  6.01it/s]
# Data for 2024-08-14 downloaded successfully.
# Data for 2024-08-15 downloaded successfully.
# Downloading data:  98%|█████████▊| 3882/3957 [11:05<00:12,  6.12it/s]
# Data for 2024-08-16 downloaded successfully.
# Data for 2024-08-17 downloaded successfully.
# Downloading data:  98%|█████████▊| 3884/3957 [11:05<00:11,  6.09it/s]
# Data for 2024-08-18 downloaded successfully.
# Data for 2024-08-19 downloaded successfully.
# Downloading data:  98%|█████████▊| 3886/3957 [11:05<00:12,  5.90it/s]
# Data for 2024-08-20 downloaded successfully.
# Data for 2024-08-21 downloaded successfully.
# Downloading data:  98%|█████████▊| 3888/3957 [11:06<00:12,  5.67it/s]
# Data for 2024-08-22 downloaded successfully.
# Data for 2024-08-23 downloaded successfully.
# Downloading data:  98%|█████████▊| 3889/3957 [11:06<00:12,  5.53it/s]
# Data for 2024-08-24 downloaded successfully.
# Downloading data:  98%|█████████▊| 3891/3957 [11:06<00:13,  5.05it/s]
# Data for 2024-08-25 downloaded successfully.
# Data for 2024-08-26 downloaded successfully.
# Downloading data:  98%|█████████▊| 3893/3957 [11:07<00:11,  5.36it/s]
# Data for 2024-08-27 downloaded successfully.
# Data for 2024-08-28 downloaded successfully.
# Downloading data:  98%|█████████▊| 3895/3957 [11:07<00:11,  5.62it/s]
# Data for 2024-08-29 downloaded successfully.
# Data for 2024-08-30 downloaded successfully.
# Downloading data:  98%|█████████▊| 3897/3957 [11:07<00:10,  5.91it/s]
# Data for 2024-08-31 downloaded successfully.
# Data for 2024-09-01 downloaded successfully.
# Downloading data:  99%|█████████▊| 3899/3957 [11:08<00:09,  6.09it/s]
# Data for 2024-09-02 downloaded successfully.
# Data for 2024-09-03 downloaded successfully.
# Downloading data:  99%|█████████▊| 3901/3957 [11:08<00:09,  6.04it/s]
# Data for 2024-09-04 downloaded successfully.
# Data for 2024-09-05 downloaded successfully.
# Downloading data:  99%|█████████▊| 3903/3957 [11:08<00:08,  6.05it/s]
# Data for 2024-09-06 downloaded successfully.
# Data for 2024-09-07 downloaded successfully.
# Downloading data:  99%|█████████▊| 3905/3957 [11:09<00:08,  6.12it/s]
# Data for 2024-09-08 downloaded successfully.
# Data for 2024-09-09 downloaded successfully.
# Downloading data:  99%|█████████▊| 3907/3957 [11:09<00:08,  6.04it/s]
# Data for 2024-09-10 downloaded successfully.
# Data for 2024-09-11 downloaded successfully.
# Downloading data:  99%|█████████▉| 3908/3957 [11:09<00:08,  6.08it/s]
# Data for 2024-09-12 downloaded successfully.
# Downloading data:  99%|█████████▉| 3910/3957 [11:09<00:08,  5.76it/s]
# Data for 2024-09-13 downloaded successfully.
# Data for 2024-09-14 downloaded successfully.
# Downloading data:  99%|█████████▉| 3912/3957 [11:10<00:07,  6.00it/s]
# Data for 2024-09-15 downloaded successfully.
# Data for 2024-09-16 downloaded successfully.
# Downloading data:  99%|█████████▉| 3914/3957 [11:10<00:07,  5.99it/s]
# Data for 2024-09-17 downloaded successfully.
# Data for 2024-09-18 downloaded successfully.
# Downloading data:  99%|█████████▉| 3916/3957 [11:10<00:06,  6.04it/s]
# Data for 2024-09-19 downloaded successfully.
# Data for 2024-09-20 downloaded successfully.
# Downloading data:  99%|█████████▉| 3918/3957 [11:11<00:06,  6.12it/s]
# Data for 2024-09-21 downloaded successfully.
# Data for 2024-09-22 downloaded successfully.
# Downloading data:  99%|█████████▉| 3920/3957 [11:11<00:05,  6.18it/s]
# Data for 2024-09-23 downloaded successfully.
# Data for 2024-09-24 downloaded successfully.
# Downloading data:  99%|█████████▉| 3922/3957 [11:11<00:05,  6.23it/s]
# Data for 2024-09-25 downloaded successfully.
# Data for 2024-09-26 downloaded successfully.
# Downloading data:  99%|█████████▉| 3924/3957 [11:12<00:05,  6.20it/s]
# Data for 2024-09-27 downloaded successfully.
# Data for 2024-09-28 downloaded successfully.
# Downloading data:  99%|█████████▉| 3926/3957 [11:12<00:04,  6.22it/s]
# Data for 2024-09-29 downloaded successfully.
# Data for 2024-09-30 downloaded successfully.
# Downloading data:  99%|█████████▉| 3928/3957 [11:12<00:04,  6.21it/s]
# Data for 2024-10-01 downloaded successfully.
# Data for 2024-10-02 downloaded successfully.
# Downloading data:  99%|█████████▉| 3930/3957 [11:13<00:04,  6.21it/s]
# Data for 2024-10-03 downloaded successfully.
# Data for 2024-10-04 downloaded successfully.
# Downloading data:  99%|█████████▉| 3932/3957 [11:13<00:04,  5.87it/s]
# Data for 2024-10-05 downloaded successfully.
# Data for 2024-10-06 downloaded successfully.
# Downloading data:  99%|█████████▉| 3934/3957 [11:13<00:03,  6.05it/s]
# Data for 2024-10-07 downloaded successfully.
# Data for 2024-10-08 downloaded successfully.
# Downloading data:  99%|█████████▉| 3936/3957 [11:14<00:03,  6.06it/s]
# Data for 2024-10-09 downloaded successfully.
# Data for 2024-10-10 downloaded successfully.
# Downloading data: 100%|█████████▉| 3938/3957 [11:14<00:03,  6.13it/s]
# Data for 2024-10-11 downloaded successfully.
# Data for 2024-10-12 downloaded successfully.
# Downloading data: 100%|█████████▉| 3940/3957 [11:14<00:02,  6.21it/s]
# Data for 2024-10-13 downloaded successfully.
# Data for 2024-10-14 downloaded successfully.
# Downloading data: 100%|█████████▉| 3942/3957 [11:15<00:02,  6.24it/s]
# Data for 2024-10-15 downloaded successfully.
# Data for 2024-10-16 downloaded successfully.
# Downloading data: 100%|█████████▉| 3944/3957 [11:15<00:02,  6.22it/s]
# Data for 2024-10-17 downloaded successfully.
# Data for 2024-10-18 downloaded successfully.
# Downloading data: 100%|█████████▉| 3946/3957 [11:15<00:01,  6.24it/s]
# Data for 2024-10-19 downloaded successfully.
# Data for 2024-10-20 downloaded successfully.
# Downloading data: 100%|█████████▉| 3948/3957 [11:16<00:01,  6.29it/s]
# Data for 2024-10-21 downloaded successfully.
# Data for 2024-10-22 downloaded successfully.
# Downloading data: 100%|█████████▉| 3950/3957 [11:16<00:01,  6.23it/s]
# Data for 2024-10-23 downloaded successfully.
# Data for 2024-10-24 downloaded successfully.
# Downloading data: 100%|█████████▉| 3952/3957 [11:16<00:00,  6.10it/s]
# Data for 2024-10-25 downloaded successfully.
# Data for 2024-10-26 downloaded successfully.
# Downloading data: 100%|█████████▉| 3954/3957 [11:17<00:00,  6.09it/s]
# Data for 2024-10-27 downloaded successfully.
# Data for 2024-10-28 downloaded successfully.
# Downloading data: 100%|█████████▉| 3956/3957 [11:17<00:00,  6.12it/s]
# Data for 2024-10-29 downloaded successfully.
# Data for 2024-10-30 downloaded successfully.
# Downloading data: 100%|██████████| 3957/3957 [11:17<00:00,  5.84it/s]
# Data for 2024-10-31 downloaded successfully.
# Data saved to historical_data.csv

# %%
import requests
from bs4 import BeautifulSoup
import re

url = 'https://www.mse.mk/daily/stats/symbolhistory/REPL'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')


publishers = []
for option in soup.select('select#publisher-dropdown option'):
    code = option.get('value')

    if re.match("^[A-Za-z]+$", code):
        publishers.append(code)

# %%
import pandas as pd

data_path = '/content/historical_data.csv'
data = pd.read_csv(data_path)


last_dates = data.groupby('publisher_code')['date'].max().to_dict()

from datetime import datetime, timedelta


end_date = datetime.today()
start_date = end_date - timedelta(days=365 * 10)


for publisher in publishers:
    last_date = last_dates.get(publisher, start_date)
    print(f"Publisher: {publisher}, Last Date: {last_date}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-ac48cec1555c> in <cell line: 7>()
#       5
#       6 # Extract last available date for each publisher
# ----> 7 last_dates = data.groupby('publisher_code')['date'].max().to_dict()
#       8
#       9 from datetime import datetime, timedelta
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'publisher_code'

# %%
print(data.columns)
# Out:
# Index(['Date', 'Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.',
#        'Volume', 'Turnover in BEST in denars', 'Total turnover in denars'],
#       dtype='object')

# %%
print(data.head())
# Out:
#         Date  Last trade price      Max      Min  Avg. Price  %chg.  Volume  \
# 0  11/8/2024           15096.0  15096.0  15096.0     15096.0  -0.01       9
# 1  11/7/2024           15098.0  15098.0  15098.0     15098.0  -0.01      17
# 2  11/6/2024           15100.0      NaN      NaN     15100.0   0.00       0
# 3  11/5/2024           15100.0  15100.0  15100.0     15100.0   0.00      11
# 4  11/4/2024           15100.0  15100.0  15100.0     15100.0   2.03       2
#
#    Turnover in BEST in denars  Total turnover in denars
# 0                      135864                    135864
# 1                      256666                    256666
# 2                           0                         0
# 3                      166100                    166100
# 4                       30200                     30200

# %%
import pandas as pd
from datetime import datetime, timedelta

data_path = '/content/historical_data.csv'
data = pd.read_csv(data_path)


data['Date'] = pd.to_datetime(data['Date'], errors='coerce')


last_date = data['Date'].max()
print(f"Last available date in the dataset: {last_date}")


end_date = datetime.today()
start_date = end_date - timedelta(days=365 * 10)


if last_date >= start_date:
    print("Data contains entries within the last 10 years.")
else:
    print("No data from the last 10 years.")
# Out:
# Last available date in the dataset: 2024-11-08 00:00:00
# Data contains entries within the last 10 years.

# %%
def fetch_data(publisher, start_date, end_date):

    return pd.DataFrame()


for publisher, last_date in last_dates.items():
    new_data = fetch_data(publisher, last_date, end_date)
    data = pd.concat([data, new_data])


data.to_csv(data_path, index=False)


data['date'] = pd.to_datetime(data['date']).dt.strftime('%d-%m-%Y')


data['price'] = data['price'].apply(lambda x: f"{x:,.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-bfadf36b9e4d> in <cell line: 7>()
#       5
#       6 # Append new data for each publisher
# ----> 7 for publisher, last_date in last_dates.items():
#       8     new_data = fetch_data(publisher, last_date, end_date)
#       9     data = pd.concat([data, new_data])
#
# NameError: name 'last_dates' is not defined

# %%
for publisher, last_date in last_dates.items():
    new_data = fetch_data(publisher, last_date, end_date)
    data = pd.concat([data, new_data], ignore_index=True)


data.to_csv(data_path, index=False)


data['Date'] = pd.to_datetime(data['Date']).dt.strftime('%d-%m-%Y')


if 'Last trade price' in data.columns:
    data['Last trade price'] = data['Last trade price'].apply(lambda x: f"{x:,.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-949295437fb3> in <cell line: 5>()
#       3
#       4 # Fetch new data for each publisher and append it
# ----> 5 for publisher, last_date in last_dates.items():
#       6     new_data = fetch_data(publisher, last_date, end_date)
#       7     data = pd.concat([data, new_data], ignore_index=True)
#
# NameError: name 'last_dates' is not defined

# %%
import pandas as pd
from datetime import datetime, timedelta


data_path = '/content/historical_data.csv'
data = pd.read_csv(data_path)


last_dates = data.groupby('publisher_code')['Date'].max().to_dict()


end_date = datetime.today()
start_date = end_date - timedelta(days=365 * 10)


def fetch_data(publisher, start_date, end_date):

    return pd.DataFrame()

for publisher, last_date in last_dates.items():
    new_data = fetch_data(publisher, last_date, end_date)
    data = pd.concat([data, new_data], ignore_index=True)

data.to_csv(data_path, index=False)


data['Date'] = pd.to_datetime(data['Date']).dt.strftime('%Y-%m-%d')


if 'Last trade price' in data.columns:
    data['Last trade price'] = data['Last trade price'].apply(lambda x: f"{x:,.2f}")

print("Updated data with new entries and formatted columns:")
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-34cb48cb1241> in <cell line: 10>()
#       8 # Extract the last available date for each publisher
#       9 # Make sure 'Date' and 'publisher_code' match actual column names in your data
# ---> 10 last_dates = data.groupby('publisher_code')['Date'].max().to_dict()
#      11
#      12 # Set the date range for fetching new data
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'publisher_code'

# %%
last_dates = data.groupby('publisher_code')['Date'].max().to_dict()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-b0b73b99b120> in <cell line: 3>()
#       1 # Create a dictionary mapping for last_dates in the beginning of your code block
#       2 # Example based on your dataset
# ----> 3 last_dates = data.groupby('publisher_code')['Date'].max().to_dict()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'publisher_code'

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
from tqdm import tqdm
import time
from google.colab import files
data_path = '/content/historical_data.csv'
data = pd.read_csv(data_path)

data['Date'] = pd.to_datetime(data['Date'], errors='coerce')

last_dates = data.groupby('Publisher')['Date'].max().to_dict()


end_date = datetime.today()
date_range = (end_date - last_dates['REPL']).days + 1


def fetch_missing_data(publisher, start_date, end_date):
    data_frames = []
    current_date = start_date
    while current_date <= end_date:
        date_str = current_date.strftime('%Y-%m-%d')
        url = f"https://www.mse.mk/daily/stats/symbolhistory/{publisher}?date={date_str}"

        for attempt in range(3):
            try:
                response = requests.get(url, timeout=10)
                if response.status_code == 200:

                    df = pd.read_html(response.content)[0]
                    df['Publisher'] = publisher
                    data_frames.append(df)
                    print(f"Data for {publisher} on {date_str} fetched successfully.")
                    break
                else:
                    print(f"Failed to fetch data for {publisher} on {date_str}. Status: {response.status_code}")
            except Exception as e:
                print(f"Error fetching data for {publisher} on {date_str}: {e}")
                time.sleep(1)

        current_date += timedelta(days=1)
    return pd.concat(data_frames, ignore_index=True)


all_new_data = []
for publisher, last_date in last_dates.items():
    if last_date < end_date:
        new_data = fetch_missing_data(publisher, last_date + timedelta(days=1), end_date)
        all_new_data.append(new_data)

if all_new_data:
    new_data_combined = pd.concat(all_new_data, ignore_index=True)

    data = pd.concat([data, new_data_combined], ignore_index=True)

    data = data.sort_values(by='Date').reset_index(drop=True)
    data.to_csv(data_path, index=False)

    print("Missing data successfully fetched and merged.")
else:
    print("No missing data found.")


files.download(data_path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-1fbb32d5373a> in <cell line: 16>()
#      14
#      15 # Get the last available date and create a 10-year date range
# ---> 16 last_dates = data.groupby('Publisher')['Date'].max().to_dict()
#      17
#      18 # Define the date range for missing data fetching
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'Publisher'

# %%
print(data.columns)
print(data.head())
# Out:
# Index(['Date', 'Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.',
#        'Volume', 'Turnover in BEST in denars', 'Total turnover in denars'],
#       dtype='object')
#         Date  Last trade price      Max      Min  Avg. Price  %chg.  Volume  \
# 0 2024-11-08           15096.0  15096.0  15096.0     15096.0  -0.01       9
# 1 2024-11-07           15098.0  15098.0  15098.0     15098.0  -0.01      17
# 2 2024-11-06           15100.0      NaN      NaN     15100.0   0.00       0
# 3 2024-11-05           15100.0  15100.0  15100.0     15100.0   0.00      11
# 4 2024-11-04           15100.0  15100.0  15100.0     15100.0   2.03       2
#
#    Turnover in BEST in denars  Total turnover in denars
# 0                      135864                    135864
# 1                      256666                    256666
# 2                           0                         0
# 3                      166100                    166100
# 4                       30200                     30200

# %%
import pandas as pd
import requests
from datetime import datetime, timedelta
from google.colab import files


data_path = '/content/historical_data.csv'
data = pd.read_csv(data_path)


data['Date'] = pd.to_datetime(data['Date'], errors='coerce')


start_date_10_years = datetime(2014, 10, 28)
end_date_10_years = datetime(2024, 10, 28)

start_date_recent = datetime(2024, 10, 28)
end_date_recent = datetime(2024, 11, 9)


def fetch_data(date):

    url = f"https://www.mse.mk/daily/stats/symbolhistory/REPL?date={date.strftime('%Y-%m-%d')}"
    response = requests.get(url)
    if response.status_code == 200:

        df = pd.read_html(response.content)[0]
        df['Date'] = date
        return df
    else:
        print(f"Failed to fetch data for {date}")
        return pd.DataFrame()

missing_dates_10_years = pd.date_range(start_date_10_years, end_date_10_years)

new_data_10_years = pd.DataFrame()
for date in missing_dates_10_years:
    data_for_date = fetch_data(date)
    new_data_10_years = pd.concat([new_data_10_years, data_for_date], ignore_index=True)

missing_dates_recent = pd.date_range(start_date_recent, end_date_recent)

new_data_recent = pd.DataFrame()
for date in missing_dates_recent:
    data_for_date = fetch_data(date)
    new_data_recent = pd.concat([new_data_recent, data_for_date], ignore_index=True)

all_data = pd.concat([data, new_data_10_years, new_data_recent], ignore_index=True).sort_values(by='Date')

all_data.to_csv(data_path, index=False)

files.download(data_path)

print("Missing data fetched and merged successfully.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-bcaa9188d775> in <cell line: 38>()
#      37 new_data_10_years = pd.DataFrame()
#      38 for date in missing_dates_10_years:
# ---> 39     data_for_date = fetch_data(date)
#      40     new_data_10_years = pd.concat([new_data_10_years, data_for_date], ignore_index=True)
#      41
#
# <ipython-input-14-bcaa9188d775> in fetch_data(date)
#      22     # Replace with your actual API or data-fetching logic
#      23     url = f"https://www.mse.mk/daily/stats/symbolhistory/REPL?date={date.strftime('%Y-%m-%d')}"
# ---> 24     response = requests.get(url)
#      25     if response.status_code == 200:
#      26         # Assume the response contains HTML that can be converted to a DataFrame
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     744
#     745         if not stream:
# --> 746             r.content
#     747
#     748         return r
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in content(self)
#     900                 self._content = None
#     901             else:
# --> 902                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     903
#     904         self._content_consumed = True
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in generate()
#     818             if hasattr(self.raw, "stream"):
#     819                 try:
# --> 820                     yield from self.raw.stream(chunk_size, decode_content=True)
#     821                 except ProtocolError as e:
#     822                     raise ChunkedEncodingError(e)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#    1058         else:
#    1059             while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1060                 data = self.read(amt=amt, decode_content=decode_content)
#    1061
#    1062                 if data:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     947                 return self._decoded_buffer.get(amt)
#     948
# --> 949         data = self._raw_read(amt)
#     950
#     951         flush_decoder = amt is None or (amt != 0 and not data)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in _raw_read(self, amt, read1)
#     871
#     872         with self._error_catcher():
# --> 873             data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     874             if amt is not None and amt != 0 and not data:
#     875                 # Platform-specific: Buggy versions of Python.
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in _fp_read(self, amt, read1)
#     854         else:
#     855             # StringIO doesn't like amt=None
# --> 856             return self._fp.read(amt) if amt is not None else self._fp.read()
#     857
#     858     def _raw_read(
#
# /usr/lib/python3.10/http/client.py in read(self, amt)
#     464                 # clip the read to the "end of response"
#     465                 amt = self.length
# --> 466             s = self.fp.read(amt)
#     467             if not s and amt:
#     468                 # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from datetime import datetime

start_date = datetime(2014, 1, 1)
end_date = datetime(2024, 10, 31)

current_date = start_date
while current_date <= end_date:
    month_end = current_date.replace(day=28) + timedelta(days=4)
    month_end = month_end - timedelta(days=month_end.day)

    url = f'https://www.mse.mk/daily/stats/symbolhistory/REPL?date={current_date.strftime("%Y-%m-%d")}'
    response = requests.get(url, timeout=30)

    if response.status_code == 200:
        print(f"Fetched data for {current_date.strftime('%Y-%m-%d')}")
    else:
        print(f"Failed to fetch data for {current_date.strftime('%Y-%m-%d')}")


    current_date = month_end + timedelta(days=1)
# Out:
# Fetched data for 2014-01-01
# Fetched data for 2014-02-01
# Fetched data for 2014-03-01
# Fetched data for 2014-04-01
# Fetched data for 2014-05-01
# Fetched data for 2014-06-01
# Fetched data for 2014-07-01
# Fetched data for 2014-08-01
# Fetched data for 2014-09-01
# Fetched data for 2014-10-01
# Fetched data for 2014-11-01
# Fetched data for 2014-12-01
# Fetched data for 2015-01-01
# Fetched data for 2015-02-01
# Fetched data for 2015-03-01
# Fetched data for 2015-04-01
# Fetched data for 2015-05-01
# Fetched data for 2015-06-01
# Fetched data for 2015-07-01
# Fetched data for 2015-08-01
# Fetched data for 2015-09-01
# Fetched data for 2015-10-01
# Fetched data for 2015-11-01
# Fetched data for 2015-12-01
# Fetched data for 2016-01-01
# Fetched data for 2016-02-01
# Fetched data for 2016-03-01
# Fetched data for 2016-04-01
# Fetched data for 2016-05-01
# Fetched data for 2016-06-01
# Fetched data for 2016-07-01
# Fetched data for 2016-08-01
# Fetched data for 2016-09-01
# Fetched data for 2016-10-01
# Fetched data for 2016-11-01
# Fetched data for 2016-12-01
# Fetched data for 2017-01-01
# Fetched data for 2017-02-01
# Fetched data for 2017-03-01
# Fetched data for 2017-04-01
# Fetched data for 2017-05-01
# Fetched data for 2017-06-01
# Fetched data for 2017-07-01
# Fetched data for 2017-08-01
# Fetched data for 2017-09-01
# Fetched data for 2017-10-01
# Fetched data for 2017-11-01
# Fetched data for 2017-12-01
# Fetched data for 2018-01-01
# Fetched data for 2018-02-01
# Fetched data for 2018-03-01
# Fetched data for 2018-04-01
# Fetched data for 2018-05-01
# Fetched data for 2018-06-01
# Fetched data for 2018-07-01
# Fetched data for 2018-08-01
# Fetched data for 2018-09-01
# Fetched data for 2018-10-01
# Fetched data for 2018-11-01
# Fetched data for 2018-12-01
# Fetched data for 2019-01-01
# Fetched data for 2019-02-01
# Fetched data for 2019-03-01
# Fetched data for 2019-04-01
# Fetched data for 2019-05-01
# Fetched data for 2019-06-01
# Fetched data for 2019-07-01
# Fetched data for 2019-08-01
# Fetched data for 2019-09-01
# Fetched data for 2019-10-01
# Fetched data for 2019-11-01
# Fetched data for 2019-12-01
# Fetched data for 2020-01-01
# Fetched data for 2020-02-01
# Fetched data for 2020-03-01
# Fetched data for 2020-04-01
# Fetched data for 2020-05-01
# Fetched data for 2020-06-01
# Fetched data for 2020-07-01
# Fetched data for 2020-08-01
# Fetched data for 2020-09-01
# Fetched data for 2020-10-01
# Fetched data for 2020-11-01
# Fetched data for 2020-12-01
# Fetched data for 2021-01-01
# Fetched data for 2021-02-01
# Fetched data for 2021-03-01
# Fetched data for 2021-04-01
# Fetched data for 2021-05-01
# Fetched data for 2021-06-01
# Fetched data for 2021-07-01
# Fetched data for 2021-08-01
# Fetched data for 2021-09-01
# Fetched data for 2021-10-01
# Fetched data for 2021-11-01
# Fetched data for 2021-12-01
# Fetched data for 2022-01-01
# Fetched data for 2022-02-01
# Fetched data for 2022-03-01
# Fetched data for 2022-04-01
# Fetched data for 2022-05-01
# Fetched data for 2022-06-01
# Fetched data for 2022-07-01
# Fetched data for 2022-08-01
# Fetched data for 2022-09-01
# Fetched data for 2022-10-01
# Fetched data for 2022-11-01
# Fetched data for 2022-12-01
# Fetched data for 2023-01-01
# Fetched data for 2023-02-01
# Fetched data for 2023-03-01
# Fetched data for 2023-04-01
# Fetched data for 2023-05-01
# Fetched data for 2023-06-01
# Fetched data for 2023-07-01
# Fetched data for 2023-08-01
# Fetched data for 2023-09-01
# Fetched data for 2023-10-01
# Fetched data for 2023-11-01
# Fetched data for 2023-12-01
# Fetched data for 2024-01-01
# Fetched data for 2024-02-01
# Fetched data for 2024-03-01
# Fetched data for 2024-04-01
# Fetched data for 2024-05-01
# Fetched data for 2024-06-01
# Fetched data for 2024-07-01
# Fetched data for 2024-08-01
# Fetched data for 2024-09-01
# Fetched data for 2024-10-01

# %%
import requests
from datetime import datetime, timedelta
import pandas as pd

start_date = datetime(2014, 1, 1)
end_date = datetime(2024, 10, 31)

current_date = start_date
all_data = []

while current_date <= end_date:
    month_end = current_date.replace(day=28) + timedelta(days=4)
    month_end = month_end - timedelta(days=month_end.day)

    url = f'https://www.mse.mk/daily/stats/symbolhistory/REPL?date={current_date.strftime("%Y-%m-%d")}'
    response = requests.get(url, timeout=30)

    if response.status_code == 200:
        print(f"Fetched data for {current_date.strftime('%Y-%m-%d')}")

        try:
            df = pd.read_html(response.content)[0]
            all_data.append(df)
        except Exception as e:
            print(f"Error processing data for {current_date.strftime('%Y-%m-%d')}: {e}")
    else:
        print(f"Failed to fetch data for {current_date.strftime('%Y-%m-%d')}")


    current_date = month_end + timedelta(days=1)

if all_data:
    merged_data = pd.concat(all_data, ignore_index=True)
    merged_data.to_csv('mse_data.csv', index=False)
    print("Data saved to mse_data.csv")
else:
    print("No data was fetched.")
# Out:
# Fetched data for 2014-01-01
# Fetched data for 2014-02-01
# Fetched data for 2014-03-01
# Fetched data for 2014-04-01
# Fetched data for 2014-05-01
# Fetched data for 2014-06-01
# Fetched data for 2014-07-01
# Fetched data for 2014-08-01
# Fetched data for 2014-09-01
# Fetched data for 2014-10-01
# Fetched data for 2014-11-01
# Fetched data for 2014-12-01
# Fetched data for 2015-01-01
# Fetched data for 2015-02-01
# Fetched data for 2015-03-01
# Fetched data for 2015-04-01
# Fetched data for 2015-05-01
# Fetched data for 2015-06-01
# Fetched data for 2015-07-01
# Fetched data for 2015-08-01
# Fetched data for 2015-09-01
# Fetched data for 2015-10-01
# Fetched data for 2015-11-01
# Fetched data for 2015-12-01
# Fetched data for 2016-01-01
# Fetched data for 2016-02-01
# Fetched data for 2016-03-01
# Fetched data for 2016-04-01
# Fetched data for 2016-05-01
# Fetched data for 2016-06-01
# Fetched data for 2016-07-01
# Fetched data for 2016-08-01
# Fetched data for 2016-09-01
# Fetched data for 2016-10-01
# Fetched data for 2016-11-01
# Fetched data for 2016-12-01
# Fetched data for 2017-01-01
# Fetched data for 2017-02-01
# Fetched data for 2017-03-01
# Fetched data for 2017-04-01
# Fetched data for 2017-05-01
# Fetched data for 2017-06-01
# Fetched data for 2017-07-01
# Fetched data for 2017-08-01
# Fetched data for 2017-09-01
# Fetched data for 2017-10-01
# Fetched data for 2017-11-01
# Fetched data for 2017-12-01
# Fetched data for 2018-01-01
# Fetched data for 2018-02-01
# Fetched data for 2018-03-01
# Fetched data for 2018-04-01
# Fetched data for 2018-05-01
# Fetched data for 2018-06-01
# Fetched data for 2018-07-01
# Fetched data for 2018-08-01
# Fetched data for 2018-09-01
# Fetched data for 2018-10-01
# Fetched data for 2018-11-01
# Fetched data for 2018-12-01
# Fetched data for 2019-01-01
# Fetched data for 2019-02-01
# Fetched data for 2019-03-01
# Fetched data for 2019-04-01
# Fetched data for 2019-05-01
# Fetched data for 2019-06-01
# Fetched data for 2019-07-01
# Fetched data for 2019-08-01
# Fetched data for 2019-09-01
# Fetched data for 2019-10-01
# Fetched data for 2019-11-01
# Fetched data for 2019-12-01
# Fetched data for 2020-01-01
# Fetched data for 2020-02-01
# Fetched data for 2020-03-01
# Fetched data for 2020-04-01
# Fetched data for 2020-05-01
# Fetched data for 2020-06-01
# Fetched data for 2020-07-01
# Fetched data for 2020-08-01
# Fetched data for 2020-09-01
# Fetched data for 2020-10-01
# Fetched data for 2020-11-01
# Fetched data for 2020-12-01
# Fetched data for 2021-01-01
# Fetched data for 2021-02-01
# Fetched data for 2021-03-01
# Fetched data for 2021-04-01
# Fetched data for 2021-05-01
# Fetched data for 2021-06-01
# Fetched data for 2021-07-01
# Fetched data for 2021-08-01
# Fetched data for 2021-09-01
# Fetched data for 2021-10-01
# Fetched data for 2021-11-01
# Fetched data for 2021-12-01
# Fetched data for 2022-01-01
# Fetched data for 2022-02-01
# Fetched data for 2022-03-01
# Fetched data for 2022-04-01
# Fetched data for 2022-05-01
# Fetched data for 2022-06-01
# Fetched data for 2022-07-01
# Fetched data for 2022-08-01
# Fetched data for 2022-09-01
# Fetched data for 2022-10-01
# Fetched data for 2022-11-01
# Fetched data for 2022-12-01
# Fetched data for 2023-01-01
# Fetched data for 2023-02-01
# Fetched data for 2023-03-01
# Fetched data for 2023-04-01
# Fetched data for 2023-05-01
# Fetched data for 2023-06-01
# Fetched data for 2023-07-01
# Fetched data for 2023-08-01
# Fetched data for 2023-09-01
# Fetched data for 2023-10-01
# Fetched data for 2023-11-01
# Fetched data for 2023-12-01
# Fetched data for 2024-01-01
# Fetched data for 2024-02-01
# Fetched data for 2024-03-01
# Fetched data for 2024-04-01
# Fetched data for 2024-05-01
# Fetched data for 2024-06-01
# Fetched data for 2024-07-01
# Fetched data for 2024-08-01
# Fetched data for 2024-09-01
# Fetched data for 2024-10-01
# Data saved to mse_data.csv

# %%
from google.colab import files
files.download('mse_data.csv')

# %%
import requests
from datetime import datetime, timedelta
import pandas as pd

start_date = datetime(2014, 10, 28)
end_date = datetime(2024, 10, 28)

current_date = start_date
all_data = []

while current_date <= end_date:
    month_end = current_date.replace(day=28) + timedelta(days=4)
    month_end = month_end - timedelta(days=month_end.day)

    url = f'https://www.mse.mk/daily/stats/symbolhistory/REPL?date={current_date.strftime("%Y-%m-%d")}'
    response = requests.get(url, timeout=30)

    if response.status_code == 200:
        print(f"Fetched data for {current_date.strftime('%Y-%m-%d')}")
        try:
            df = pd.read_html(response.content)[0]

            if 'Date' in df.columns:
                df['Date'] = df['Date'].apply(lambda x: x if x != '####' else None)

            if not df.empty:
                all_data.append(df)
            else:
                print(f"No data for {current_date.strftime('%Y-%m-%d')}")
        except Exception as e:
            print(f"Error processing data for {current_date.strftime('%Y-%m-%d')}: {e}")
    else:
        print(f"Failed to fetch data for {current_date.strftime('%Y-%m-%d')}")

    current_date = month_end + timedelta(days=1)

if all_data:
    merged_data = pd.concat(all_data, ignore_index=True)

    merged_data = merged_data.fillna('Missing')

    merged_data.to_csv('mse_data1.csv', index=False)
    print("Data saved to mse_data1.csv")
else:
    print("No data was fetched.")
# Out:
# Fetched data for 2014-10-28
# Fetched data for 2014-11-01
# Fetched data for 2014-12-01
# Fetched data for 2015-01-01
# Fetched data for 2015-02-01
# Fetched data for 2015-03-01
# Fetched data for 2015-04-01
# Fetched data for 2015-05-01
# Fetched data for 2015-06-01
# Fetched data for 2015-07-01
# Fetched data for 2015-08-01
# Fetched data for 2015-09-01
# Fetched data for 2015-10-01
# Fetched data for 2015-11-01
# Fetched data for 2015-12-01
# Fetched data for 2016-01-01
# Fetched data for 2016-02-01
# Fetched data for 2016-03-01
# Fetched data for 2016-04-01
# Fetched data for 2016-05-01
# Fetched data for 2016-06-01
# Fetched data for 2016-07-01
# Fetched data for 2016-08-01
# Fetched data for 2016-09-01
# Fetched data for 2016-10-01
# Fetched data for 2016-11-01
# Fetched data for 2016-12-01
# Fetched data for 2017-01-01
# Fetched data for 2017-02-01
# Fetched data for 2017-03-01
# Fetched data for 2017-04-01
# Fetched data for 2017-05-01
# Fetched data for 2017-06-01
# Fetched data for 2017-07-01
# Fetched data for 2017-08-01
# Fetched data for 2017-09-01
# Fetched data for 2017-10-01
# Fetched data for 2017-11-01
# Fetched data for 2017-12-01
# Fetched data for 2018-01-01
# Fetched data for 2018-02-01
# Fetched data for 2018-03-01
# Fetched data for 2018-04-01
# Fetched data for 2018-05-01
# Fetched data for 2018-06-01
# Fetched data for 2018-07-01
# Fetched data for 2018-08-01
# Fetched data for 2018-09-01
# Fetched data for 2018-10-01
# Fetched data for 2018-11-01
# Fetched data for 2018-12-01
# Fetched data for 2019-01-01
# Fetched data for 2019-02-01
# Fetched data for 2019-03-01
# Fetched data for 2019-04-01
# Fetched data for 2019-05-01
# Fetched data for 2019-06-01
# Fetched data for 2019-07-01
# Fetched data for 2019-08-01
# Fetched data for 2019-09-01
# Fetched data for 2019-10-01
# Fetched data for 2019-11-01
# Fetched data for 2019-12-01
# Fetched data for 2020-01-01
# Fetched data for 2020-02-01
# Fetched data for 2020-03-01
# Fetched data for 2020-04-01
# Fetched data for 2020-05-01
# Fetched data for 2020-06-01
# Fetched data for 2020-07-01
# Fetched data for 2020-08-01
# Fetched data for 2020-09-01
# Fetched data for 2020-10-01
# Fetched data for 2020-11-01
# Fetched data for 2020-12-01
# Fetched data for 2021-01-01
# Fetched data for 2021-02-01
# Fetched data for 2021-03-01
# Fetched data for 2021-04-01
# Fetched data for 2021-05-01
# Fetched data for 2021-06-01
# Fetched data for 2021-07-01
# Fetched data for 2021-08-01
# Fetched data for 2021-09-01
# Fetched data for 2021-10-01
# Fetched data for 2021-11-01
# Fetched data for 2021-12-01
# Fetched data for 2022-01-01
# Fetched data for 2022-02-01
# Fetched data for 2022-03-01
# Fetched data for 2022-04-01
# Fetched data for 2022-05-01
# Fetched data for 2022-06-01
# Fetched data for 2022-07-01
# Fetched data for 2022-08-01
# Fetched data for 2022-09-01
# Fetched data for 2022-10-01
# Fetched data for 2022-11-01
# Fetched data for 2022-12-01
# Fetched data for 2023-01-01
# Fetched data for 2023-02-01
# Fetched data for 2023-03-01
# Fetched data for 2023-04-01
# Fetched data for 2023-05-01
# Fetched data for 2023-06-01
# Fetched data for 2023-07-01
# Fetched data for 2023-08-01
# Fetched data for 2023-09-01
# Fetched data for 2023-10-01
# Fetched data for 2023-11-01
# Fetched data for 2023-12-01
# Fetched data for 2024-01-01
# Fetched data for 2024-02-01
# Fetched data for 2024-03-01
# Fetched data for 2024-04-01
# Fetched data for 2024-05-01
# Fetched data for 2024-06-01
# Fetched data for 2024-07-01
# Fetched data for 2024-08-01
# Fetched data for 2024-09-01
# Fetched data for 2024-10-01
# Data saved to mse_data1.csv

# %%
from google.colab import files
files.download('mse_data1.csv')

# %%
import requests
from datetime import datetime, timedelta
import pandas as pd


start_date = datetime(2014, 1, 1)
end_date = datetime(2024, 10, 31)

current_date = start_date
all_data = []

while current_date <= end_date:
    month_end = current_date.replace(day=28) + timedelta(days=4)
    month_end = month_end - timedelta(days=month_end.day)

    url = f'https://www.mse.mk/daily/stats/symbolhistory/REPL?date={current_date.strftime("%Y-%m-%d")}'
    response = requests.get(url, timeout=30)

    if response.status_code == 200:
        print(f"Fetched data for {current_date.strftime('%Y-%m-%d')}")
        try:
            df = pd.read_html(response.content)[0]

            df = df.applymap(lambda x: None if x == '####' else x)

            df = df.dropna(axis=1, how='any')

            df = df.dropna(how='all')

            if not df.empty:
                all_data.append(df)
            else:
                print(f"No valid data for {current_date.strftime('%Y-%m-%d')}")
        except Exception as e:
            print(f"Error processing data for {current_date.strftime('%Y-%m-%d')}: {e}")
    else:
        print(f"Failed to fetch data for {current_date.strftime('%Y-%m-%d')}")

    current_date = month_end + timedelta(days=1)

if all_data:
    merged_data = pd.concat(all_data, ignore_index=True)

    merged_data.to_csv('mse_data_cleaned_full.csv', index=False)
    print("Data saved to mse_data_cleaned_full.csv")
else:
    print("No data was fetched.")
# Out:
# Fetched data for 2014-01-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-02-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-03-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-04-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-05-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-06-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-07-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-08-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-09-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-10-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-11-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-12-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-01-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-02-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-03-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-04-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-05-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-06-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-07-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-08-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-09-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-10-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-11-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-12-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-01-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-02-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-03-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-04-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-05-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-06-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-07-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-08-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-09-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-10-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-11-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-12-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-01-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-02-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-03-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-04-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-05-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-06-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-07-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-08-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-09-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-10-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-11-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-12-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-01-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-02-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-03-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-04-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-05-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-06-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-07-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-08-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-09-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-10-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-11-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-12-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-01-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-02-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-03-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-04-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-05-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-06-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-07-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-08-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-09-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-10-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-11-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-12-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-01-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-02-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-03-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-04-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-05-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-06-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-07-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-08-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-09-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-10-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-11-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-12-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-01-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-02-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-03-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-04-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-05-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-06-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-07-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-08-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-09-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-10-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-11-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-12-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-01-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-02-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-03-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-04-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-05-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-06-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-07-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-08-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-09-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-10-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-11-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-12-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-01-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-02-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-03-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-04-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-05-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-06-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-07-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-08-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-09-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-10-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-11-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-12-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-01-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-02-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-03-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-04-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-05-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-06-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-07-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-08-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-09-01
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-10-01
# Data saved to mse_data_cleaned_full.csv
# <ipython-input-23-aa75604b7dc2>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)

# %%
from google.colab import files
files.download('mse_data_cleaned_full.csv')

# %%
import requests
from datetime import datetime, timedelta
import pandas as pd

start_date = datetime(2014, 1, 1)
end_date = datetime(2024, 10, 31)

current_date = start_date
all_data = []

while current_date <= end_date:
    month_end = current_date.replace(day=28) + timedelta(days=4)
    month_end = month_end - timedelta(days=month_end.day)

    url = f'https://www.mse.mk/daily/stats/symbolhistory/REPL?date={current_date.strftime("%Y-%m-%d")}'
    response = requests.get(url, timeout=30)

    if response.status_code == 200:
        print(f"Fetched data for {current_date.strftime('%Y-%m-%d')}")
        try:
            df = pd.read_html(response.content)[0]

            df = df.applymap(lambda x: None if x == '####' else x)

            df = df.dropna(axis=1, how='all')
            df = df.loc[:, (df != 0).any(axis=0)]


            df = df.dropna(how='all')


            df = df[~(df == 0).any(axis=1)]

            if not df.empty:
                all_data.append(df)
            else:
                print(f"No valid data for {current_date.strftime('%Y-%m-%d')}")
        except Exception as e:
            print(f"Error processing data for {current_date.strftime('%Y-%m-%d')}: {e}")
    else:
        print(f"Failed to fetch data for {current_date.strftime('%Y-%m-%d')}")


    current_date = month_end + timedelta(days=1)


if all_data:
    merged_data = pd.concat(all_data, ignore_index=True)


    merged_data.to_csv('mse_data_cleaned_no_zeros_and_invalid_columns.csv', index=False)
    print("Data saved to mse_data_cleaned_no_zeros_and_invalid_columns.csv")
else:
    print("No data was fetched.")
# Out:
# Fetched data for 2014-01-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-02-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-03-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-04-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-05-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-06-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-07-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-08-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-09-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-10-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-11-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-12-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-01-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-02-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-03-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-04-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-05-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-06-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-07-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-08-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-09-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-10-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-11-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-12-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-01-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-02-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-03-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-04-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-05-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-06-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-07-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-08-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-09-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-10-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-11-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-12-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-01-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-02-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-03-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-04-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-05-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-06-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-07-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-08-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-09-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-10-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-11-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-12-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-01-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-02-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-03-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-04-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-05-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-06-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-07-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-08-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-09-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-10-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-11-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-12-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-01-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-02-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-03-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-04-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-05-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-06-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-07-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-08-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-09-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-10-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-11-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-12-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-01-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-02-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-03-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-04-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-05-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-06-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-07-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-08-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-09-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-10-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-11-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-12-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-01-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-02-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-03-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-04-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-05-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-06-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-07-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-08-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-09-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-10-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-11-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-12-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-01-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-02-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-03-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-04-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-05-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-06-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-07-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-08-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-09-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-10-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-11-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-12-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-01-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-02-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-03-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-04-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-05-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-06-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-07-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-08-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-09-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-10-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-11-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-12-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-01-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-02-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-03-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-04-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-05-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-06-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-07-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-08-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-09-01
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-10-01
# Data saved to mse_data_cleaned_no_zeros_and_invalid_columns.csv
# <ipython-input-25-7ccb5a911f70>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)

# %%
from google.colab import files
files.download('mse_data_cleaned_no_zeros_and_invalid_columns.csv')

# %%
import requests
from datetime import datetime, timedelta
import pandas as pd


start_date = datetime(2014, 1, 1)
end_date = datetime(2024, 10, 31)

current_date = start_date
all_data = []

while current_date <= end_date:
    month_end = current_date.replace(day=28) + timedelta(days=4)
    month_end = month_end - timedelta(days=month_end.day)

    url = f'https://www.mse.mk/daily/stats/symbolhistory/REPL?date={current_date.strftime("%Y-%m-%d")}'
    response = requests.get(url, timeout=30)


    if response.status_code == 200:
        print(f"Fetched data for {current_date.strftime('%Y-%m-%d')}")
        try:
            df = pd.read_html(response.content)[0]

            df = df.applymap(lambda x: None if x == '####' else x)

            df = df.dropna(axis=1, how='all')
            df = df.loc[:, (df != 0).any(axis=0)]
            df = df.loc[:, (df >= 0).any(axis=0)]

            df = df[~(df == 0).any(axis=1)]
            df = df[~(df < 0).any(axis=1)]
            df = df.dropna(how='all')
            df = df[~df.applymap(lambda x: isinstance(x, str)).any(axis=1)]

            if not df.empty:
                all_data.append(df)
            else:
                print(f"No valid data for {current_date.strftime('%Y-%m-%d')}")
        except Exception as e:
            print(f"Error processing data for {current_date.strftime('%Y-%m-%d')}: {e}")
    else:
        print(f"Failed to fetch data for {current_date.strftime('%Y-%m-%d')}")

    current_date = month_end + timedelta(days=1)

if all_data:
    merged_data = pd.concat(all_data, ignore_index=True)


    merged_data.to_csv('mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', index=False)
    print("Data saved to mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv")
else:
    print("No data was fetched.")
# Out:
# Fetched data for 2014-01-01
# Error processing data for 2014-01-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-02-01
# Error processing data for 2014-02-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-03-01
# Error processing data for 2014-03-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-04-01
# Error processing data for 2014-04-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-05-01
# Error processing data for 2014-05-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-06-01
# Error processing data for 2014-06-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-07-01
# Error processing data for 2014-07-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-08-01
# Error processing data for 2014-08-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-09-01
# Error processing data for 2014-09-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-10-01
# Error processing data for 2014-10-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-11-01
# Error processing data for 2014-11-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-12-01
# Error processing data for 2014-12-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-01-01
# Error processing data for 2015-01-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-02-01
# Error processing data for 2015-02-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-03-01
# Error processing data for 2015-03-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-04-01
# Error processing data for 2015-04-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-05-01
# Error processing data for 2015-05-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-06-01
# Error processing data for 2015-06-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-07-01
# Error processing data for 2015-07-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-08-01
# Error processing data for 2015-08-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-09-01
# Error processing data for 2015-09-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-10-01
# Error processing data for 2015-10-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-11-01
# Error processing data for 2015-11-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-12-01
# Error processing data for 2015-12-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-01-01
# Error processing data for 2016-01-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-02-01
# Error processing data for 2016-02-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-03-01
# Error processing data for 2016-03-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-04-01
# Error processing data for 2016-04-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-05-01
# Error processing data for 2016-05-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-06-01
# Error processing data for 2016-06-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-07-01
# Error processing data for 2016-07-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-08-01
# Error processing data for 2016-08-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-09-01
# Error processing data for 2016-09-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-10-01
# Error processing data for 2016-10-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-11-01
# Error processing data for 2016-11-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-12-01
# Error processing data for 2016-12-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-01-01
# Error processing data for 2017-01-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-02-01
# Error processing data for 2017-02-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-03-01
# Error processing data for 2017-03-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-04-01
# Error processing data for 2017-04-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-05-01
# Error processing data for 2017-05-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-06-01
# Error processing data for 2017-06-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-07-01
# Error processing data for 2017-07-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-08-01
# Error processing data for 2017-08-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-09-01
# Error processing data for 2017-09-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-10-01
# Error processing data for 2017-10-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-11-01
# Error processing data for 2017-11-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-12-01
# Error processing data for 2017-12-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-01-01
# Error processing data for 2018-01-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-02-01
# Error processing data for 2018-02-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-03-01
# Error processing data for 2018-03-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-04-01
# Error processing data for 2018-04-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-05-01
# Error processing data for 2018-05-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-06-01
# Error processing data for 2018-06-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-07-01
# Error processing data for 2018-07-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-08-01
# Error processing data for 2018-08-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-09-01
# Error processing data for 2018-09-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-10-01
# Error processing data for 2018-10-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-11-01
# Error processing data for 2018-11-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-12-01
# Error processing data for 2018-12-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-01-01
# Error processing data for 2019-01-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-02-01
# Error processing data for 2019-02-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-03-01
# Error processing data for 2019-03-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-04-01
# Error processing data for 2019-04-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-05-01
# Error processing data for 2019-05-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-06-01
# Error processing data for 2019-06-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-07-01
# Error processing data for 2019-07-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-08-01
# Error processing data for 2019-08-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-09-01
# Error processing data for 2019-09-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-10-01
# Error processing data for 2019-10-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-11-01
# Error processing data for 2019-11-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-12-01
# Error processing data for 2019-12-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-01-01
# Error processing data for 2020-01-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-02-01
# Error processing data for 2020-02-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-03-01
# Error processing data for 2020-03-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-04-01
# Error processing data for 2020-04-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-05-01
# Error processing data for 2020-05-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-06-01
# Error processing data for 2020-06-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-07-01
# Error processing data for 2020-07-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-08-01
# Error processing data for 2020-08-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-09-01
# Error processing data for 2020-09-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-10-01
# Error processing data for 2020-10-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-11-01
# Error processing data for 2020-11-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-12-01
# Error processing data for 2020-12-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-01-01
# Error processing data for 2021-01-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-02-01
# Error processing data for 2021-02-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-03-01
# Error processing data for 2021-03-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-04-01
# Error processing data for 2021-04-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-05-01
# Error processing data for 2021-05-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-06-01
# Error processing data for 2021-06-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-07-01
# Error processing data for 2021-07-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-08-01
# Error processing data for 2021-08-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-09-01
# Error processing data for 2021-09-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-10-01
# Error processing data for 2021-10-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-11-01
# Error processing data for 2021-11-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-12-01
# Error processing data for 2021-12-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-01-01
# Error processing data for 2022-01-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-02-01
# Error processing data for 2022-02-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-03-01
# Error processing data for 2022-03-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-04-01
# Error processing data for 2022-04-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-05-01
# Error processing data for 2022-05-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-06-01
# Error processing data for 2022-06-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-07-01
# Error processing data for 2022-07-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-08-01
# Error processing data for 2022-08-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-09-01
# Error processing data for 2022-09-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-10-01
# Error processing data for 2022-10-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-11-01
# Error processing data for 2022-11-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-12-01
# Error processing data for 2022-12-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-01-01
# Error processing data for 2023-01-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-02-01
# Error processing data for 2023-02-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-03-01
# Error processing data for 2023-03-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-04-01
# Error processing data for 2023-04-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-05-01
# Error processing data for 2023-05-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-06-01
# Error processing data for 2023-06-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-07-01
# Error processing data for 2023-07-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-08-01
# Error processing data for 2023-08-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-09-01
# Error processing data for 2023-09-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-10-01
# Error processing data for 2023-10-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-11-01
# Error processing data for 2023-11-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-12-01
# Error processing data for 2023-12-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-01-01
# Error processing data for 2024-01-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-02-01
# Error processing data for 2024-02-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-03-01
# Error processing data for 2024-03-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-04-01
# Error processing data for 2024-04-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-05-01
# Error processing data for 2024-05-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-06-01
# Error processing data for 2024-06-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-07-01
# Error processing data for 2024-07-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-08-01
# Error processing data for 2024-08-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-09-01
# Error processing data for 2024-09-01: '>=' not supported between instances of 'str' and 'int'
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-10-01
# Error processing data for 2024-10-01: '>=' not supported between instances of 'str' and 'int'
# No data was fetched.
# <ipython-input-29-1218d261f326>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)

# %%
import requests
from datetime import datetime, timedelta
import pandas as pd


start_date = datetime(2014, 1, 1)
end_date = datetime(2024, 10, 31)

current_date = start_date
all_data = []

while current_date <= end_date:
    month_end = current_date.replace(day=28) + timedelta(days=4)
    month_end = month_end - timedelta(days=month_end.day)

    url = f'https://www.mse.mk/daily/stats/symbolhistory/REPL?date={current_date.strftime("%Y-%m-%d")}'
    response = requests.get(url, timeout=30)


    if response.status_code == 200:
        print(f"Fetched data for {current_date.strftime('%Y-%m-%d')}")
        try:
            df = pd.read_html(response.content)[0]

            df = df.applymap(lambda x: None if x == '####' else x)

            df = df.apply(pd.to_numeric, errors='coerce')

            df = df.dropna(axis=1, how='all')
            df = df.loc[:, (df != 0).any(axis=0)]
            df = df.loc[:, (df >= 0).any(axis=0)]

            df = df[~(df == 0).any(axis=1)]
            df = df[~(df < 0).any(axis=1)]
            df = df.dropna(how='all')

            if not df.empty:
                all_data.append(df)
            else:
                print(f"No valid data for {current_date.strftime('%Y-%m-%d')}")
        except Exception as e:
            print(f"Error processing data for {current_date.strftime('%Y-%m-%d')}: {e}")
    else:
        print(f"Failed to fetch data for {current_date.strftime('%Y-%m-%d')}")

    current_date = month_end + timedelta(days=1)

if all_data:
    merged_data = pd.concat(all_data, ignore_index=True)

    merged_data.to_csv('mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', index=False)
    print("Data saved to mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv")
else:
    print("No data was fetched.")
# Out:
# Fetched data for 2014-01-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-02-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-03-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-04-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-05-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-06-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-07-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-08-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-09-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-10-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-11-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2014-12-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-01-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-02-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-03-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-04-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-05-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-06-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-07-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-08-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-09-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-10-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-11-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2015-12-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-01-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-02-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-03-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-04-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-05-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-06-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-07-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-08-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-09-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-10-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-11-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2016-12-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-01-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-02-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-03-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-04-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-05-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-06-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-07-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-08-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-09-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-10-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-11-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2017-12-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-01-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-02-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-03-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-04-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-05-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-06-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-07-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-08-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-09-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-10-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2018-11-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Failed to fetch data for 2018-12-01
# Fetched data for 2019-01-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Failed to fetch data for 2019-02-01
# Failed to fetch data for 2019-03-01
# Failed to fetch data for 2019-04-01
# Fetched data for 2019-05-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-06-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-07-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-08-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-09-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-10-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-11-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2019-12-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-01-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-02-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-03-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-04-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-05-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-06-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-07-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-08-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-09-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-10-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-11-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2020-12-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-01-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-02-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-03-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-04-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-05-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-06-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-07-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-08-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-09-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-10-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-11-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2021-12-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-01-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-02-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-03-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-04-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-05-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-06-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-07-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-08-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-09-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-10-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-11-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2022-12-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-01-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-02-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-03-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-04-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-05-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-06-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-07-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-08-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-09-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-10-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-11-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2023-12-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-01-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-02-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-03-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-04-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-05-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-06-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-07-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-08-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-09-01
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)
# Fetched data for 2024-10-01
# Data saved to mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv
# <ipython-input-31-ac3a299e2b54>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: None if x == '####' else x)

# %%
from google.colab import files
files.download('mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv')

# %%
# !git clone https://github.com/jovana-angjelkovska/DIANS.git
# Out:
# Cloning into 'DIANS'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !pip install pandas requests sqlalchemy sqlite3
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (2.0.36)
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3

# %%
# !git config --global user.name "jovana-angjelkovska"
# !git config --global user.email "jovana.angjelkovska@students.finki.ukim.mk"


# !git add .


# !git commit -m


# !git push origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# !git config --global user.name "jovana-angjelkovska"
# !git config --global user.email "jovana.angjelkovska@students.finki.ukim.mk"

# %%
# !git clone https://github.com/jovana-angjelkovska/DIANS.git
# Out:
# fatal: destination path 'DIANS' already exists and is not an empty directory.

# %%
import shutil


shutil.copy('/content/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', '/content/https://github.com/jovana-angjelkovska/DIANS.git')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-a593adc43f2a> in <cell line: 4>()
#       2
#       3 # Replace 'your_file' with the actual file or directory you want to move
# ----> 4 shutil.copy('/content/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', '/content/https://github.com/jovana-angjelkovska/DIANS.git')
#
# /usr/lib/python3.10/shutil.py in copy(src, dst, follow_symlinks)
#     415     if os.path.isdir(dst):
#     416         dst = os.path.join(dst, os.path.basename(src))
# --> 417     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     418     copymode(src, dst, follow_symlinks=follow_symlinks)
#     419     return dst
#
# /usr/lib/python3.10/shutil.py in copyfile(src, dst, follow_symlinks)
#     254         with open(src, 'rb') as fsrc:
#     255             try:
# --> 256                 with open(dst, 'wb') as fdst:
#     257                     # macOS
#     258                     if _HAS_FCOPYFILE:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/https://github.com/jovana-angjelkovska/DIANS.git'

# %%
# %cd /content/DIANS
# Out:
# /content/DIANS

# %%
# !git add mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv
# Out:
# fatal: pathspec 'mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv' did not match any files

# %%
# !git commit -m "Added cleaned data file"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
import pandas as pd

data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv')

print(data.head())
# Out:
#    Last trade price      Max      Min  Avg. Price  %chg.  Volume  \
# 0           15100.0  15100.0  15100.0     15100.0   2.03       2
# 1           14800.0  14800.0  14800.0     14800.0   0.68      12
# 2           14700.0  14700.0  14700.0     14700.0   0.28      34
# 3           14700.0  14700.0  14700.0     14700.0   1.38      40
# 4           14790.0  14790.0  14790.0     14790.0   1.69       3
#
#    Turnover in BEST in denars  Total turnover in denars
# 0                       30200                     30200
# 1                      177600                    177600
# 2                      499800                    499800
# 3                      588000                    588000
# 4                       44370                     44370

# %%
print(data.info())

print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Last trade price            630 non-null    float64
#  1   Max                         630 non-null    float64
#  2   Min                         630 non-null    float64
#  3   Avg. Price                  630 non-null    float64
#  4   %chg.                       630 non-null    float64
#  5   Volume                      630 non-null    int64
#  6   Turnover in BEST in denars  630 non-null    int64
#  7   Total turnover in denars    630 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 39.5 KB
# None
#        Last trade price           Max           Min    Avg. Price       %chg.  \
# count        630.000000    630.000000    630.000000    630.000000  630.000000
# mean       14818.000000  14818.000000  14818.000000  14818.000000    1.212000
# std          147.412662    147.412662    147.412662    147.412662    0.645102
# min        14700.000000  14700.000000  14700.000000  14700.000000    0.280000
# 25%        14700.000000  14700.000000  14700.000000  14700.000000    0.680000
# 50%        14790.000000  14790.000000  14790.000000  14790.000000    1.380000
# 75%        14800.000000  14800.000000  14800.000000  14800.000000    1.690000
# max        15100.000000  15100.000000  15100.000000  15100.000000    2.030000
#
#            Volume  Turnover in BEST in denars  Total turnover in denars
# count  630.000000                  630.000000                630.000000
# mean    18.200000               267994.000000             267994.000000
# std     15.866935               232934.858238             232934.858238
# min      2.000000                30200.000000              30200.000000
# 25%      3.000000                44370.000000              44370.000000
# 50%     12.000000               177600.000000             177600.000000
# 75%     34.000000               499800.000000             499800.000000
# max     40.000000               588000.000000             588000.000000

# %%
data['Date'] = pd.to_datetime(data['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-1a72a8b5b870> in <cell line: 1>()
# ----> 1 data['Date'] = pd.to_datetime(data['Date'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Date'

# %%
print(data.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars'],
#       dtype='object')

# %%
data.rename(columns={'timestamp': 'Date'}, inplace=True)

# %%
data['Date'] = pd.to_datetime(data['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-1a72a8b5b870> in <cell line: 1>()
# ----> 1 data['Date'] = pd.to_datetime(data['Date'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Date'

# %%
import pandas as pd

data['Date'] = pd.date_range(start='2022-01-01', periods=len(data), freq='D')

data['Date'] = pd.to_datetime(data['Date'])

# %%
data = data.sort_values(by='Date')

# %%
# Simple Moving Average (SMA)
data['SMA_20'] = data['Close'].rolling(window=20).mean()

# Exponential Moving Average (EMA)
data['EMA_20'] = data['Close'].ewm(span=20, adjust=False).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-613a679ff1b6> in <cell line: 2>()
#       1 # Simple Moving Average (SMA)
# ----> 2 data['SMA_20'] = data['Close'].rolling(window=20).mean()
#       3
#       4 # Exponential Moving Average (EMA)
#       5 data['EMA_20'] = data['Close'].ewm(span=20, adjust=False).mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Close'

# %%
def calculate_moving_averages(data, periods):
    for period in periods:
        data[f'SMA_{period}'] = data['close'].rolling(window=period).mean()
        data[f'EMA_{period}'] = data['close'].ewm(span=period, adjust=False).mean()
    return data

data = calculate_moving_averages(data, periods=[10, 20, 50])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-bc0770b12d50> in <cell line: 9>()
#       7
#       8 # Example: Calculate 10-day, 20-day, 50-day moving averages
# ----> 9 data = calculate_moving_averages(data, periods=[10, 20, 50])
#
# <ipython-input-10-bc0770b12d50> in calculate_moving_averages(data, periods)
#       2 def calculate_moving_averages(data, periods):
#       3     for period in periods:
# ----> 4         data[f'SMA_{period}'] = data['close'].rolling(window=period).mean()
#       5         data[f'EMA_{period}'] = data['close'].ewm(span=period, adjust=False).mean()
#       6     return data
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'close'

# %%
print(data.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars', 'Date'],
#       dtype='object')

# %%
data['SMA_20'] = data['Last trade price'].rolling(window=20).mean()

data['EMA_20'] = data['Last trade price'].ewm(span=20, adjust=False).mean()

# %%
pip install ta
# Out:
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ta) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ta) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->ta) (1.17.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=23f163899c78d1eecc39b949ff29bbdc03079e31db04d8de9a4bf84f2e89d6e9
#   Stored in directory: /root/.cache/pip/wheels/5f/67/4f/8a9f252836e053e532c6587a3230bc72a4deb16b03a829610b
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.11.0

# %%
from ta.momentum import RSIIndicator
import matplotlib.pyplot as plt

rsi = RSIIndicator(close=data['Last trade price'], window=14)
data['RSI'] = rsi.rsi()

plt.figure(figsize=(14, 7))
plt.plot(data['Date'], data['Last trade price'], label='Close Price', color='blue')
plt.plot(data['Date'], data['SMA_20'], label='SMA (20)', color='red')
plt.plot(data['Date'], data['EMA_20'], label='EMA (20)', color='green')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.plot(data['Date'], data['Last trade price'], label='Last Trade Price', color='blue')
plt.plot(data['Date'], data['SMA_20'], label='SMA (20)', color='red')

plt.scatter(data[data['Buy_Signal']]['Date'], data[data['Buy_Signal']]['Last trade price'], marker='^', color='green', label='Buy Signal', alpha=1)

plt.scatter(data[data['Sell_Signal']]['Date'], data[data['Sell_Signal']]['Last trade price'], marker='v', color='red', label='Sell Signal', alpha=1)

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Buy_Signal'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-53ea344e0c59> in <cell line: 7>()
#       5
#       6 # Plot Buy signals
# ----> 7 plt.scatter(data[data['Buy_Signal']]['Date'], data[data['Buy_Signal']]['Last trade price'], marker='^', color='green', label='Buy Signal', alpha=1)
#       8
#       9 # Plot Sell signals
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Buy_Signal'

# %%
data['Buy_Signal'] = (data['Last trade price'] > data['SMA_20']) & (data['Last trade price'].shift(1) <= data['SMA_20'].shift(1))

data['Sell_Signal'] = (data['Last trade price'] < data['SMA_20']) & (data['Last trade price'].shift(1) >= data['SMA_20'].shift(1))

# %%
print(data.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars', 'Date',
#        'SMA_20', 'EMA_20', 'RSI', 'Buy_Signal', 'Sell_Signal'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(data['Date'], data['Last trade price'], label='Last Trade Price', color='blue')
plt.plot(data['Date'], data['SMA_20'], label='SMA (20)', color='red')
plt.plot(data['Date'], data['EMA_20'], label='EMA (20)', color='green')

plt.scatter(data[data['Buy_Signal']].Date, data[data['Buy_Signal']].['Last trade price'], marker='^', color='green', label='Buy Signal', alpha=1)
plt.scatter(data[data['Sell_Signal']].Date, data[data['Sell_Signal']].['Last trade price'], marker='v', color='red', label='Sell Signal', alpha=1)

plt.xlabel('Date')
plt.ylabel('Price (in Denars)')
plt.title('Buy and Sell Signals with SMA/EMA')
plt.legend()

plt.show()
# Out:
#   File "<ipython-input-21-32eb11f8d10f>", line 10
#     plt.scatter(data[data['Buy_Signal']].Date, data[data['Buy_Signal']].['Last trade price'], marker='^', color='green', label='Buy Signal', alpha=1)
#                                                                         ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(data['Date'], data['Last trade price'], label='Last Trade Price', color='blue')
plt.plot(data['Date'], data['SMA_20'], label='SMA (20)', color='red')
plt.plot(data['Date'], data['EMA_20'], label='EMA (20)', color='green')

plt.scatter(data[data['Buy_Signal']].Date, data[data['Buy_Signal']]['Last trade price'], marker='^', color='green', label='Buy Signal', alpha=1)
plt.scatter(data[data['Sell_Signal']].Date, data[data['Sell_Signal']]['Last trade price'], marker='v', color='red', label='Sell Signal', alpha=1)

plt.xlabel('Date')
plt.ylabel('Price (in Denars)')
plt.title('Buy and Sell Signals with SMA/EMA')
plt.legend()

plt.show()

# %%
pip install pandas numpy ta matplotlib
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: ta in /usr/local/lib/python3.10/dist-packages (0.11.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import ta
import matplotlib.pyplot as plt

data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Date'])

data['SMA_20'] = data['Last trade price'].rolling(window=20).mean()
data['EMA_20'] = data['Last trade price'].ewm(span=20, adjust=False).mean()

data['RSI'] = ta.momentum.RSIIndicator(data['Last trade price'], window=14).rsi()

data['MACD'] = ta.trend.MACD(data['Last trade price']).macd()
data['MACD_signal'] = ta.trend.MACD(data['Last trade price']).macd_signal()

data['Buy_Signal'] = np.where(data['Last trade price'] > data['SMA_20'], 1, 0)
data['Sell_Signal'] = np.where(data['Last trade price'] < data['SMA_20'], 1, 0)

plt.figure(figsize=(10, 6))
plt.plot(data['Date'], data['Last trade price'], label='Price', color='black')
plt.plot(data['Date'], data['SMA_20'], label='SMA 20', color='blue')
plt.plot(data['Date'], data['EMA_20'], label='EMA 20', color='red')

plt.scatter(data[data['Buy_Signal'] == 1].Date,
            data[data['Buy_Signal'] == 1]['Last trade price'],
            marker='^', color='green', label='Buy Signal', alpha=1)

plt.scatter(data[data['Sell_Signal'] == 1].Date,
            data[data['Sell_Signal'] == 1]['Last trade price'],
            marker='v', color='red', label='Sell Signal', alpha=1)

plt.legend()
plt.title('Stock Price with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-2bf6ba9c4835> in <cell line: 7>()
#       5
#       6 # Load the data (assuming your data contains 'Date' and 'Last trade price' columns)
# ----> 7 data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Date'])
#       8
#       9 # Calculate SMA and EMA for 20 periods
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#     159
#     160         # error: Cannot determine type of 'names'
# --> 161         self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
#     162         self._set_noconvert_columns()
#     163
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/base_parser.py in _validate_parse_dates_presence(self, columns)
#     241         )
#     242         if missing_cols:
# --> 243             raise ValueError(
#     244                 f"Missing column provided to 'parse_dates': '{missing_cols}'"
#     245             )
#
# ValueError: Missing column provided to 'parse_dates': 'Date'

# %%
data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv')
print(data.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars'],
#       dtype='object')

# %%
data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Trade Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-81dba342ead0> in <cell line: 1>()
# ----> 1 data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Trade Date'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#     159
#     160         # error: Cannot determine type of 'names'
# --> 161         self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
#     162         self._set_noconvert_columns()
#     163
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/base_parser.py in _validate_parse_dates_presence(self, columns)
#     241         )
#     242         if missing_cols:
# --> 243             raise ValueError(
#     244                 f"Missing column provided to 'parse_dates': '{missing_cols}'"
#     245             )
#
# ValueError: Missing column provided to 'parse_dates': 'Trade Date'

# %%
data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['DateColumn'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-5c186eb9afb3> in <cell line: 2>()
#       1 # Assuming the date column is named 'DateColumn'
# ----> 2 data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['DateColumn'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#     159
#     160         # error: Cannot determine type of 'names'
# --> 161         self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
#     162         self._set_noconvert_columns()
#     163
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/base_parser.py in _validate_parse_dates_presence(self, columns)
#     241         )
#     242         if missing_cols:
# --> 243             raise ValueError(
#     244                 f"Missing column provided to 'parse_dates': '{missing_cols}'"
#     245             )
#
# ValueError: Missing column provided to 'parse_dates': 'DateColumn'

# %%
import pandas as pd

data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv')

data['Date'] = pd.date_range(start='2022-01-01', periods=len(data), freq='D')

print(data.head())
# Out:
#    Last trade price      Max      Min  Avg. Price  %chg.  Volume  \
# 0           15100.0  15100.0  15100.0     15100.0   2.03       2
# 1           14800.0  14800.0  14800.0     14800.0   0.68      12
# 2           14700.0  14700.0  14700.0     14700.0   0.28      34
# 3           14700.0  14700.0  14700.0     14700.0   1.38      40
# 4           14790.0  14790.0  14790.0     14790.0   1.69       3
#
#    Turnover in BEST in denars  Total turnover in denars       Date
# 0                       30200                     30200 2022-01-01
# 1                      177600                    177600 2022-01-02
# 2                      499800                    499800 2022-01-03
# 3                      588000                    588000 2022-01-04
# 4                       44370                     44370 2022-01-05

# %%
import pandas as pd

data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv')

data['Date'] = pd.to_datetime(data['Date'])

print(data.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-3eefcd05fafc> in <cell line: 7>()
#       5
#       6 # Convert the 'Date' column to datetime format
# ----> 7 data['Date'] = pd.to_datetime(data['Date'])
#       8
#       9 # Display the first few rows to verify
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Date'

# %%
data.columns = data.columns.str.strip()

print(data.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars'],
#       dtype='object')

# %%
import pandas as pd

date_range = pd.date_range(start='2022-01-01', periods=len(data), freq='D')

data['Date'] = date_range

print(data.head())
# Out:
#    Last trade price      Max      Min  Avg. Price  %chg.  Volume  \
# 0           15100.0  15100.0  15100.0     15100.0   2.03       2
# 1           14800.0  14800.0  14800.0     14800.0   0.68      12
# 2           14700.0  14700.0  14700.0     14700.0   0.28      34
# 3           14700.0  14700.0  14700.0     14700.0   1.38      40
# 4           14790.0  14790.0  14790.0     14790.0   1.69       3
#
#    Turnover in BEST in denars  Total turnover in denars       Date
# 0                       30200                     30200 2022-01-01
# 1                      177600                    177600 2022-01-02
# 2                      499800                    499800 2022-01-03
# 3                      588000                    588000 2022-01-04
# 4                       44370                     44370 2022-01-05

# %%
print(data.head())
# Out:
#    Last trade price      Max      Min  Avg. Price  %chg.  Volume  \
# 0           15100.0  15100.0  15100.0     15100.0   2.03       2
# 1           14800.0  14800.0  14800.0     14800.0   0.68      12
# 2           14700.0  14700.0  14700.0     14700.0   0.28      34
# 3           14700.0  14700.0  14700.0     14700.0   1.38      40
# 4           14790.0  14790.0  14790.0     14790.0   1.69       3
#
#    Turnover in BEST in denars  Total turnover in denars       Date
# 0                       30200                     30200 2022-01-01
# 1                      177600                    177600 2022-01-02
# 2                      499800                    499800 2022-01-03
# 3                      588000                    588000 2022-01-04
# 4                       44370                     44370 2022-01-05

# %%
from textblob import TextBlob
import requests

def get_news_from_api():
    return ["The company is doing great!", "The stock price fell due to bad earnings", "The company announced a new product"]

def analyze_sentiment(news_list):
    sentiment_results = []
    for article in news_list:
        blob = TextBlob(article)
        sentiment = blob.sentiment.polarity
        sentiment_results.append(sentiment)
    return sentiment_results

news_articles = get_news_from_api()
sentiments = analyze_sentiment(news_articles)

for news, sentiment in zip(news_articles, sentiments):
    recommendation = "Buy" if sentiment > 0 else "Sell"
    print(f"News: {news} | Sentiment: {sentiment:.2f} | Recommendation: {recommendation}")
# Out:
# News: The company is doing great! | Sentiment: 1.00 | Recommendation: Buy
# News: The stock price fell due to bad earnings | Sentiment: -0.41 | Recommendation: Sell
# News: The company announced a new product | Sentiment: 0.14 | Recommendation: Buy

# %%
import pandas as pd
import numpy as np
import ta
import matplotlib.pyplot as plt

data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Date'])

data['SMA_20'] = data['Last trade price'].rolling(window=20).mean()
data['EMA_20'] = data['Last trade price'].ewm(span=20, adjust=False).mean()

data['RSI'] = ta.momentum.RSIIndicator(data['Last trade price'], window=14).rsi()

data['MACD'] = ta.trend.MACD(data['Last trade price']).macd()
data['MACD_signal'] = ta.trend.MACD(data['Last trade price']).macd_signal()

data['Buy_Signal'] = np.where(data['Last trade price'] > data['SMA_20'], 1, 0)
data['Sell_Signal'] = np.where(data['Last trade price'] < data['SMA_20'], 1, 0)

plt.figure(figsize=(10, 6))
plt.plot(data['Date'], data['Last trade price'], label='Price', color='black')
plt.plot(data['Date'], data['SMA_20'], label='SMA 20', color='blue')
plt.plot(data['Date'], data['EMA_20'], label='EMA 20', color='red')

plt.scatter(data[data['Buy_Signal'] == 1].Date,
            data[data['Buy_Signal'] == 1]['Last trade price'],
            marker='^', color='green', label='Buy Signal', alpha=1)

plt.scatter(data[data['Sell_Signal'] == 1].Date,
            data[data['Sell_Signal'] == 1]['Last trade price'],
            marker='v', color='red', label='Sell Signal', alpha=1)

plt.legend()
plt.title('Stock Price with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-2bf6ba9c4835> in <cell line: 7>()
#       5
#       6 # Load the data (assuming your data contains 'Date' and 'Last trade price' columns)
# ----> 7 data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Date'])
#       8
#       9 # Calculate SMA and EMA for 20 periods
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#     159
#     160         # error: Cannot determine type of 'names'
# --> 161         self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
#     162         self._set_noconvert_columns()
#     163
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/base_parser.py in _validate_parse_dates_presence(self, columns)
#     241         )
#     242         if missing_cols:
# --> 243             raise ValueError(
#     244                 f"Missing column provided to 'parse_dates': '{missing_cols}'"
#     245             )
#
# ValueError: Missing column provided to 'parse_dates': 'Date'

# %%
print(data.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars', 'Date'],
#       dtype='object')

# %%
data['Date'] = pd.to_datetime(data['Date'])

print(data.dtypes)
# Out:
# Last trade price                     float64
# Max                                  float64
# Min                                  float64
# Avg. Price                           float64
# %chg.                                float64
# Volume                                 int64
# Turnover in BEST in denars             int64
# Total turnover in denars               int64
# Date                          datetime64[ns]
# dtype: object

# %%
data['SMA_20'] = data['Last trade price'].rolling(window=20).mean()
data['EMA_20'] = data['Last trade price'].ewm(span=20, adjust=False).mean()

print(data[['SMA_20', 'EMA_20']].isnull().sum())
# Out:
# SMA_20    19
# EMA_20     0
# dtype: int64

# %%
data['RSI'] = ta.momentum.RSIIndicator(data['Last trade price'], window=14).rsi()

data['MACD'] = ta.trend.MACD(data['Last trade price']).macd()
data['MACD_signal'] = ta.trend.MACD(data['Last trade price']).macd_signal()

print(data[['RSI', 'MACD', 'MACD_signal']].isnull().sum())
# Out:
# RSI            13
# MACD           25
# MACD_signal    33
# dtype: int64

# %%
data.dropna(subset=['RSI', 'MACD', 'MACD_signal'], inplace=True)

print(data[['RSI', 'MACD', 'MACD_signal']].isnull().sum())
# Out:
# RSI            0
# MACD           0
# MACD_signal    0
# dtype: int64

# %%
data['RSI'].fillna(method='ffill', inplace=True)
data['MACD'].fillna(method='ffill', inplace=True)
data['MACD_signal'].fillna(method='ffill', inplace=True)

print(data[['RSI', 'MACD', 'MACD_signal']].isnull().sum())
# Out:
# RSI            0
# MACD           0
# MACD_signal    0
# dtype: int64
# <ipython-input-43-81f99bc9b6e1>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['RSI'].fillna(method='ffill', inplace=True)
# <ipython-input-43-81f99bc9b6e1>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['RSI'].fillna(method='ffill', inplace=True)
# <ipython-input-43-81f99bc9b6e1>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['MACD'].fillna(method='ffill', inplace=True)
# <ipython-input-43-81f99bc9b6e1>:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['MACD'].fillna(method='ffill', inplace=True)
# <ipython-input-43-81f99bc9b6e1>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['MACD_signal'].fillna(method='ffill', inplace=True)
# <ipython-input-43-81f99bc9b6e1>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['MACD_signal'].fillna(method='ffill', inplace=True)

# %%
data['RSI'] = data['RSI'].ffill()
data['MACD'] = data['MACD'].ffill()
data['MACD_signal'] = data['MACD_signal'].ffill()

print(data[['RSI', 'MACD', 'MACD_signal']].isnull().sum())
# Out:
# RSI            0
# MACD           0
# MACD_signal    0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import ta
import matplotlib.pyplot as plt

data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Date'])

data['SMA_20'] = data['Last trade price'].rolling(window=20).mean()
data['EMA_20'] = data['Last trade price'].ewm(span=20, adjust=False).mean()

data['RSI'] = ta.momentum.RSIIndicator(data['Last trade price'], window=14).rsi()

data['MACD'] = ta.trend.MACD(data['Last trade price']).macd()
data['MACD_signal'] = ta.trend.MACD(data['Last trade price']).macd_signal()

data['RSI'] = data['RSI'].ffill()
data['MACD'] = data['MACD'].ffill()
data['MACD_signal'] = data['MACD_signal'].ffill()

data['Buy_Signal'] = np.where(data['Last trade price'] > data['SMA_20'], 1, 0)
data['Sell_Signal'] = np.where(data['Last trade price'] < data['SMA_20'], 1, 0)

plt.figure(figsize=(10, 6))
plt.plot(data['Date'], data['Last trade price'], label='Price', color='black')
plt.plot(data['Date'], data['SMA_20'], label='SMA 20', color='blue')
plt.plot(data['Date'], data['EMA_20'], label='EMA 20', color='red')

plt.scatter(data[data['Buy_Signal'] == 1].Date,
            data[data['Buy_Signal'] == 1]['Last trade price'],
            marker='^', color='green', label='Buy Signal', alpha=1)

plt.scatter(data[data['Sell_Signal'] == 1].Date,
            data[data['Sell_Signal'] == 1]['Last trade price'],
            marker='v', color='red', label='Sell Signal', alpha=1)

plt.legend()
plt.title('Stock Price with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-a0a7cb45bedf> in <cell line: 7>()
#       5
#       6 # Load the data (assuming your data contains 'Date' and 'Last trade price' columns)
# ----> 7 data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Date'])
#       8
#       9 # Calculate SMA and EMA for 20 periods
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#     159
#     160         # error: Cannot determine type of 'names'
# --> 161         self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
#     162         self._set_noconvert_columns()
#     163
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/base_parser.py in _validate_parse_dates_presence(self, columns)
#     241         )
#     242         if missing_cols:
# --> 243             raise ValueError(
#     244                 f"Missing column provided to 'parse_dates': '{missing_cols}'"
#     245             )
#
# ValueError: Missing column provided to 'parse_dates': 'Date'

# %%
import pandas as pd

data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv')
print(data.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars'],
#       dtype='object')

# %%
plt.plot(data.index, data['Last trade price'], label='Price', color='black')
plt.plot(data.index, data['SMA_20'], label='SMA 20', color='blue')
plt.plot(data.index, data['EMA_20'], label='EMA 20', color='red')

plt.scatter(data.index[data['Buy_Signal'] == 1],
            data[data['Buy_Signal'] == 1]['Last trade price'],
            marker='^', color='green', label='Buy Signal', alpha=1)

plt.scatter(data.index[data['Sell_Signal'] == 1],
            data[data['Sell_Signal'] == 1]['Last trade price'],
            marker='v', color='red', label='Sell Signal', alpha=1)

plt.legend()
plt.title('Stock Price with Buy/Sell Signals')
plt.xlabel('Index')
plt.ylabel('Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SMA_20'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-fcb509b6d67d> in <cell line: 3>()
#       1 # If you don't have a 'Date' column, use the index as x-axis
#       2 plt.plot(data.index, data['Last trade price'], label='Price', color='black')
# ----> 3 plt.plot(data.index, data['SMA_20'], label='SMA 20', color='blue')
#       4 plt.plot(data.index, data['EMA_20'], label='EMA 20', color='red')
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'SMA_20'

# %%
data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['correct_column_name'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-a28703c3e62e> in <cell line: 1>()
# ----> 1 data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['correct_column_name'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#     159
#     160         # error: Cannot determine type of 'names'
# --> 161         self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
#     162         self._set_noconvert_columns()
#     163
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/base_parser.py in _validate_parse_dates_presence(self, columns)
#     241         )
#     242         if missing_cols:
# --> 243             raise ValueError(
#     244                 f"Missing column provided to 'parse_dates': '{missing_cols}'"
#     245             )
#
# ValueError: Missing column provided to 'parse_dates': 'correct_column_name'

# %%
plt.plot(data.index, data['Last trade price'], label='Price', color='black')
plt.plot(data.index, data['SMA_20'], label='SMA 20', color='blue')
plt.plot(data.index, data['EMA_20'], label='EMA 20', color='red')

plt.scatter(data.index[data['Buy_Signal'] == 1],
            data[data['Buy_Signal'] == 1]['Last trade price'],
            marker='^', color='green', label='Buy Signal', alpha=1)

plt.scatter(data.index[data['Sell_Signal'] == 1],
            data[data['Sell_Signal'] == 1]['Last trade price'],
            marker='v', color='red', label='Sell Signal', alpha=1)

plt.legend()
plt.title('Stock Price with Buy/Sell Signals')
plt.xlabel('Index')
plt.ylabel('Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SMA_20'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-fcb509b6d67d> in <cell line: 3>()
#       1 # If you don't have a 'Date' column, use the index as x-axis
#       2 plt.plot(data.index, data['Last trade price'], label='Price', color='black')
# ----> 3 plt.plot(data.index, data['SMA_20'], label='SMA 20', color='blue')
#       4 plt.plot(data.index, data['EMA_20'], label='EMA 20', color='red')
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'SMA_20'

# %%
data['SMA_20'] = data['Last trade price'].rolling(window=20).mean()

# %%
print(data.columns)
print(data.head())
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars', 'SMA_20'],
#       dtype='object')
#    Last trade price      Max      Min  Avg. Price  %chg.  Volume  \
# 0           15100.0  15100.0  15100.0     15100.0   2.03       2
# 1           14800.0  14800.0  14800.0     14800.0   0.68      12
# 2           14700.0  14700.0  14700.0     14700.0   0.28      34
# 3           14700.0  14700.0  14700.0     14700.0   1.38      40
# 4           14790.0  14790.0  14790.0     14790.0   1.69       3
#
#    Turnover in BEST in denars  Total turnover in denars  SMA_20
# 0                       30200                     30200     NaN
# 1                      177600                    177600     NaN
# 2                      499800                    499800     NaN
# 3                      588000                    588000     NaN
# 4                       44370                     44370     NaN

# %%
data['SMA_20'].fillna(method='ffill', inplace=True)
data['SMA_20'].fillna(method='bfill', inplace=True)
# Out:
# <ipython-input-54-c62ec46f765b>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['SMA_20'].fillna(method='ffill', inplace=True)  # forward fill
# <ipython-input-54-c62ec46f765b>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['SMA_20'].fillna(method='ffill', inplace=True)  # forward fill
# <ipython-input-54-c62ec46f765b>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['SMA_20'].fillna(method='bfill', inplace=True)  # backward fill
# <ipython-input-54-c62ec46f765b>:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['SMA_20'].fillna(method='bfill', inplace=True)  # backward fill

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['Date'], data['Last trade price'], label='Price', color='black')
plt.plot(data['Date'], data['SMA_20'], label='SMA 20', color='blue')

plt.scatter(data[data['Buy_Signal'] == 1].Date,
            data[data['Buy_Signal'] == 1]['Last trade price'],
            marker='^', color='green', label='Buy Signal', alpha=1)

plt.scatter(data[data['Sell_Signal'] == 1].Date,
            data[data['Sell_Signal'] == 1]['Last trade price'],
            marker='v', color='red', label='Sell Signal', alpha=1)

plt.legend()
plt.title('Stock Price with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-5687278487dc> in <cell line: 3>()
#       1 # Visualize the indicators
#       2 plt.figure(figsize=(10, 6))
# ----> 3 plt.plot(data['Date'], data['Last trade price'], label='Price', color='black')
#       4 plt.plot(data['Date'], data['SMA_20'], label='SMA 20', color='blue')
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Date'

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['Avg. Price'], data['SMA_20'], label='SMA 20', color='blue')

plt.scatter(data[data['Buy_Signal'] == 1].index,
            data[data['Buy_Signal'] == 1]['Last trade price'],
            marker='^', color='green', label='Buy Signal', alpha=1)

plt.scatter(data[data['Sell_Signal'] == 1].index,
            data[data['Sell_Signal'] == 1]['Last trade price'],
            marker='v', color='red', label='Sell Signal', alpha=1)

plt.legend()
plt.title('Stock Price with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Buy_Signal'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-3995a5d4bb53> in <cell line: 5>()
#       3 plt.plot(data['Avg. Price'], data['SMA_20'], label='SMA 20', color='blue')
#       4
# ----> 5 plt.scatter(data[data['Buy_Signal'] == 1].index,
#       6             data[data['Buy_Signal'] == 1]['Last trade price'],
#       7             marker='^', color='green', label='Buy Signal', alpha=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Buy_Signal'

# %%
print(data.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars', 'SMA_20'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import ta
import matplotlib.pyplot as plt

data = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv')

data['SMA_20'] = data['Last trade price'].rolling(window=20).mean()
data['EMA_20'] = data['Last trade price'].ewm(span=20, adjust=False).mean()

data['RSI'] = ta.momentum.RSIIndicator(data['Last trade price'], window=14).rsi()

data['MACD'] = ta.trend.MACD(data['Last trade price']).macd()
data['MACD_signal'] = ta.trend.MACD(data['Last trade price']).macd_signal()

data['Buy_Signal'] = np.where(data['Last trade price'] > data['SMA_20'], 1, 0)
data['Sell_Signal'] = np.where(data['Last trade price'] < data['SMA_20'], 1, 0)

plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Last trade price'], label='Price', color='black')
plt.plot(data.index, data['SMA_20'], label='SMA 20', color='blue')
plt.plot(data.index, data['EMA_20'], label='EMA 20', color='red')

plt.scatter(data[data['Buy_Signal'] == 1].index,
            data[data['Buy_Signal'] == 1]['Last trade price'],
            marker='^', color='green', label='Buy Signal', alpha=1)

plt.scatter(data[data['Sell_Signal'] == 1].index,
            data[data['Sell_Signal'] == 1]['Last trade price'],
            marker='v', color='red', label='Sell Signal', alpha=1)

plt.legend()
plt.title('Stock Price with Buy/Sell Signals')
plt.xlabel('Index')
plt.ylabel('Price')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ta

df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Date'])

df['RSI'] = ta.momentum.RSIIndicator(df['Last trade price'], window=14).rsi()

macd = ta.trend.MACD(df['Last trade price'])
df['MACD'] = macd.macd()
df['MACD_signal'] = macd.macd_signal()

stochastic = ta.momentum.StochasticOscillator(df['Last trade price'], df['Min'], df['Max'], window=14)
df['Stochastic'] = stochastic.stoch()

plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Last trade price'], label='Price', color='black')
plt.plot(df['Date'], df['RSI'], label='RSI (14)', color='blue')
plt.plot(df['Date'], df['MACD'], label='MACD', color='green')
plt.plot(df['Date'], df['MACD_signal'], label='MACD Signal', color='red')
plt.plot(df['Date'], df['Stochastic'], label='Stochastic Oscillator', color='purple')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-cfbb28e22499> in <cell line: 7>()
#       5
#       6 # Load your data (ensure 'Date' is properly parsed as a datetime column)
# ----> 7 df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Date'])
#       8
#       9 # Calculate the 14-day RSI (Relative Strength Index)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#     159
#     160         # error: Cannot determine type of 'names'
# --> 161         self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
#     162         self._set_noconvert_columns()
#     163
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/base_parser.py in _validate_parse_dates_presence(self, columns)
#     241         )
#     242         if missing_cols:
# --> 243             raise ValueError(
#     244                 f"Missing column provided to 'parse_dates': '{missing_cols}'"
#     245             )
#
# ValueError: Missing column provided to 'parse_dates': 'Date'

# %%
import pandas as pd

df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv')

print(df.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars'],
#       dtype='object')

# %%
import pandas as pd

df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv')

print(df.head())
# Out:
#    Last trade price      Max      Min  Avg. Price  %chg.  Volume  \
# 0           15100.0  15100.0  15100.0     15100.0   2.03       2
# 1           14800.0  14800.0  14800.0     14800.0   0.68      12
# 2           14700.0  14700.0  14700.0     14700.0   0.28      34
# 3           14700.0  14700.0  14700.0     14700.0   1.38      40
# 4           14790.0  14790.0  14790.0     14790.0   1.69       3
#
#    Turnover in BEST in denars  Total turnover in denars
# 0                       30200                     30200
# 1                      177600                    177600
# 2                      499800                    499800
# 3                      588000                    588000
# 4                       44370                     44370

# %%
df['Date'] = pd.date_range(start='2020-01-01', periods=len(df), freq='D')

df['Date'] = pd.to_datetime(df['Date'])

print(df.head())
# Out:
#    Last trade price      Max      Min  Avg. Price  %chg.  Volume  \
# 0           15100.0  15100.0  15100.0     15100.0   2.03       2
# 1           14800.0  14800.0  14800.0     14800.0   0.68      12
# 2           14700.0  14700.0  14700.0     14700.0   0.28      34
# 3           14700.0  14700.0  14700.0     14700.0   1.38      40
# 4           14790.0  14790.0  14790.0     14790.0   1.69       3
#
#    Turnover in BEST in denars  Total turnover in denars       Date
# 0                       30200                     30200 2020-01-01
# 1                      177600                    177600 2020-01-02
# 2                      499800                    499800 2020-01-03
# 3                      588000                    588000 2020-01-04
# 4                       44370                     44370 2020-01-05

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ta

df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Date'])

df['RSI'] = ta.momentum.RSIIndicator(df['Last trade price'], window=14).rsi()

macd = ta.trend.MACD(df['Last trade price'])
df['MACD'] = macd.macd()
df['MACD_signal'] = macd.macd_signal()

stochastic = ta.momentum.StochasticOscillator(df['Last trade price'], df['Min'], df['Max'], window=14)
df['Stochastic'] = stochastic.stoch()

plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Last trade price'], label='Price', color='black')
plt.plot(df['Date'], df['RSI'], label='RSI (14)', color='blue')
plt.plot(df['Date'], df['MACD'], label='MACD', color='green')
plt.plot(df['Date'], df['MACD_signal'], label='MACD Signal', color='red')
plt.plot(df['Date'], df['Stochastic'], label='Stochastic Oscillator', color='purple')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-cfbb28e22499> in <cell line: 7>()
#       5
#       6 # Load your data (ensure 'Date' is properly parsed as a datetime column)
# ----> 7 df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Date'])
#       8
#       9 # Calculate the 14-day RSI (Relative Strength Index)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#     159
#     160         # error: Cannot determine type of 'names'
# --> 161         self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
#     162         self._set_noconvert_columns()
#     163
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/base_parser.py in _validate_parse_dates_presence(self, columns)
#     241         )
#     242         if missing_cols:
# --> 243             raise ValueError(
#     244                 f"Missing column provided to 'parse_dates': '{missing_cols}'"
#     245             )
#
# ValueError: Missing column provided to 'parse_dates': 'Date'

# %%
df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-2cc38f72fe54> in <cell line: 1>()
# ----> 1 df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Date'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#     159
#     160         # error: Cannot determine type of 'names'
# --> 161         self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
#     162         self._set_noconvert_columns()
#     163
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/base_parser.py in _validate_parse_dates_presence(self, columns)
#     241         )
#     242         if missing_cols:
# --> 243             raise ValueError(
#     244                 f"Missing column provided to 'parse_dates': '{missing_cols}'"
#     245             )
#
# ValueError: Missing column provided to 'parse_dates': 'Date'

# %%
print(df.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars', 'Date'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars', 'Date'],
#       dtype='object')

# %%
df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv')

df.columns = df.columns.str.strip()

df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

print(df['Date'].head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-4c7a002306a0> in <cell line: 8>()
#       6
#       7 # Convert 'Date' column to datetime manually
# ----> 8 df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
#       9
#      10 # Verify the Date conversion
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Date'

# %%
df.rename(columns={'<incorrect_column_name>': 'Date'}, inplace=True)

print(df.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars'],
#       dtype='object')

# %%
df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv')

print(df.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ta

df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Date'])

df['RSI'] = ta.momentum.RSIIndicator(df['Last trade price'], window=14).rsi()

macd = ta.trend.MACD(df['Last trade price'])
df['MACD'] = macd.macd()
df['MACD_signal'] = macd.macd_signal()

stochastic = ta.momentum.StochasticOscillator(df['Last trade price'], df['Min'], df['Max'], window=14)
df['Stochastic'] = stochastic.stoch()

plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Last trade price'], label='Price', color='black')
plt.plot(df['Date'], df['RSI'], label='RSI (14)', color='blue')
plt.plot(df['Date'], df['MACD'], label='MACD', color='green')
plt.plot(df['Date'], df['MACD_signal'], label='MACD Signal', color='red')
plt.plot(df['Date'], df['Stochastic'], label='Stochastic Oscillator', color='purple')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-cfbb28e22499> in <cell line: 7>()
#       5
#       6 # Load your data (ensure 'Date' is properly parsed as a datetime column)
# ----> 7 df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv', parse_dates=['Date'])
#       8
#       9 # Calculate the 14-day RSI (Relative Strength Index)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#     159
#     160         # error: Cannot determine type of 'names'
# --> 161         self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
#     162         self._set_noconvert_columns()
#     163
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/base_parser.py in _validate_parse_dates_presence(self, columns)
#     241         )
#     242         if missing_cols:
# --> 243             raise ValueError(
#     244                 f"Missing column provided to 'parse_dates': '{missing_cols}'"
#     245             )
#
# ValueError: Missing column provided to 'parse_dates': 'Date'

# %%
import pandas as pd

df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv')

start_date = pd.to_datetime('2020-01-01')
date_range = pd.date_range(start=start_date, periods=len(df), freq='D')

df['Date'] = date_range

print(df.head())
# Out:
#    Last trade price      Max      Min  Avg. Price  %chg.  Volume  \
# 0           15100.0  15100.0  15100.0     15100.0   2.03       2
# 1           14800.0  14800.0  14800.0     14800.0   0.68      12
# 2           14700.0  14700.0  14700.0     14700.0   0.28      34
# 3           14700.0  14700.0  14700.0     14700.0   1.38      40
# 4           14790.0  14790.0  14790.0     14790.0   1.69       3
#
#    Turnover in BEST in denars  Total turnover in denars       Date
# 0                       30200                     30200 2020-01-01
# 1                      177600                    177600 2020-01-02
# 2                      499800                    499800 2020-01-03
# 3                      588000                    588000 2020-01-04
# 4                       44370                     44370 2020-01-05

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv')

df.columns = df.columns.str.strip()

df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

print(df['Date'].head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-b56c146a3ee4> in <cell line: 11>()
#       9
#      10 # Convert 'Date' column to datetime manually (if not done yet)
# ---> 11 df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
#      12
#      13 # Verify the Date conversion
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Date'

# %%
print(df.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

print(df.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars'],
#       dtype='object')

# %%
if 'Date' in df.columns:
    print("Date column found!")
else:
    print("Date column not found.")
# Out:
# Date column not found.

# %%
for index, column in enumerate(df.columns):
    print(f"Index {index}: '{column}'")
# Out:
# Index 0: 'Last trade price'
# Index 1: 'Max'
# Index 2: 'Min'
# Index 3: 'Avg. Price'
# Index 4: '%chg.'
# Index 5: 'Volume'
# Index 6: 'Turnover in BEST in denars'
# Index 7: 'Total turnover in denars'

# %%
df.rename(columns={'<old_name>': 'Date'}, inplace=True)

print(df.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars'],
#       dtype='object')

# %%
print(df.head())
# Out:
#    Last trade price      Max      Min  Avg. Price  %chg.  Volume  \
# 0           15100.0  15100.0  15100.0     15100.0   2.03       2
# 1           14800.0  14800.0  14800.0     14800.0   0.68      12
# 2           14700.0  14700.0  14700.0     14700.0   0.28      34
# 3           14700.0  14700.0  14700.0     14700.0   1.38      40
# 4           14790.0  14790.0  14790.0     14790.0   1.69       3
#
#    Turnover in BEST in denars  Total turnover in denars
# 0                       30200                     30200
# 1                      177600                    177600
# 2                      499800                    499800
# 3                      588000                    588000
# 4                       44370                     44370

# %%
df['Date'] = pd.date_range(start='2020-01-01', periods=len(df), freq='D')

# %%
import pandas as pd

df = pd.read_csv('/mse_data_cleaned_no_zeros_negatives_and_invalid_columns.csv')

df['Date'] = pd.date_range(start='2020-01-01', periods=len(df), freq='D')

print(df.head())
# Out:
#    Last trade price      Max      Min  Avg. Price  %chg.  Volume  \
# 0           15100.0  15100.0  15100.0     15100.0   2.03       2
# 1           14800.0  14800.0  14800.0     14800.0   0.68      12
# 2           14700.0  14700.0  14700.0     14700.0   0.28      34
# 3           14700.0  14700.0  14700.0     14700.0   1.38      40
# 4           14790.0  14790.0  14790.0     14790.0   1.69       3
#
#    Turnover in BEST in denars  Total turnover in denars       Date
# 0                       30200                     30200 2020-01-01
# 1                      177600                    177600 2020-01-02
# 2                      499800                    499800 2020-01-03
# 3                      588000                    588000 2020-01-04
# 4                       44370                     44370 2020-01-05

# %%
df['Price Change'] = df['Last trade price'].diff()

df['Gain'] = df['Price Change'].where(df['Price Change'] > 0, 0)
df['Loss'] = -df['Price Change'].where(df['Price Change'] < 0, 0)

df['Avg Gain'] = df['Gain'].rolling(window=14).mean()
df['Avg Loss'] = df['Loss'].rolling(window=14).mean()

df['RS'] = df['Avg Gain'] / df['Avg Loss']

df['RSI'] = 100 - (100 / (1 + df['RS']))

print(df[['Date', 'RSI']].tail())
# Out:
#           Date        RSI
# 625 2021-09-17  57.142857
# 626 2021-09-18  52.173913
# 627 2021-09-19  50.000000
# 628 2021-09-20  48.051948
# 629 2021-09-21  42.583732

# %%
overbought = df[df['RSI'] > 70]
oversold = df[df['RSI'] < 30]

print("Overbought Dates (RSI > 70):")
print(overbought[['Date', 'RSI']])

print("\nOversold Dates (RSI < 30):")
print(oversold[['Date', 'RSI']])
# Out:
# Overbought Dates (RSI > 70):
# Empty DataFrame
# Columns: [Date, RSI]
# Index: []
#
# Oversold Dates (RSI < 30):
# Empty DataFrame
# Columns: [Date, RSI]
# Index: []

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['RSI'], label='14-Day RSI')
plt.axhline(70, color='red', linestyle='--', label='Overbought (70)')
plt.axhline(30, color='green', linestyle='--', label='Oversold (30)')

plt.scatter(overbought['Date'], overbought['RSI'], color='red', label='Overbought', zorder=5)
plt.scatter(oversold['Date'], oversold['RSI'], color='green', label='Oversold', zorder=5)

plt.title('14-Day RSI')
plt.xlabel('Date')
plt.ylabel('RSI')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(df['Date'], df['RSI'], label='14-Day RSI', color='blue', linewidth=2)

plt.axhline(70, color='red', linestyle='--', label='Overbought (70)')
plt.axhline(30, color='green', linestyle='--', label='Oversold (30)')

overbought = df[df['RSI'] > 70]
plt.scatter(overbought['Date'], overbought['RSI'], color='red', label='Overbought', zorder=5)

oversold = df[df['RSI'] < 30]
plt.scatter(oversold['Date'], oversold['RSI'], color='green', label='Oversold', zorder=5)

plt.title('14-Day RSI')
plt.xlabel('Date')
plt.ylabel('RSI')

plt.legend()

plt.xticks(rotation=45)

plt.tight_layout()

plt.show()

# %%
pip install vaderSentiment pandas requests beautifulsoup4
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

def analyze_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)['compound']
    if sentiment_score >= 0.05:
        return 'Positive'
    elif sentiment_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# %%
import requests
from bs4 import BeautifulSoup

def get_news(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    paragraphs = soup.find_all('p')
    news_content = " ".join([p.text for p in paragraphs])
    return news_content

news_url = 'https://www.mse.com.mk'
news_text = get_news(news_url)

sentiment = analyze_sentiment(news_text)
print("Sentiment:", sentiment)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465             try:
# --> 466                 self._validate_conn(conn)
#     467             except (SocketTimeout, BaseSSLError) as e:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1094         if conn.is_closed:
# -> 1095             conn.connect()
#    1096
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in connect(self)
#     729
# --> 730             sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     731                 sock=sock,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     908
# --> 909     ssl_sock = ssl_wrap_socket(
#     910         sock=sock,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     468
# --> 469     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     470     return ssl_sock
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     512
# --> 513     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# /usr/lib/python3.10/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     512         # ctx._wrap_socket()
# --> 513         return self.sslsocket_class._create(
#     514             sock=sock,
#
# /usr/lib/python3.10/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1099                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1100                     self.do_handshake()
#    1101             except (OSError, ValueError):
#
# /usr/lib/python3.10/ssl.py in do_handshake(self, block)
#    1370                 self.settimeout(None)
# -> 1371             self._sslobj.do_handshake()
#    1372         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.mse.com.mk'. (_ssl.c:1007)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788             # Make the request on the HTTPConnection object
# --> 789             response = self._make_request(
#     790                 conn,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489                 new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490             raise new_e
#     491
#
# SSLError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.mse.com.mk'. (_ssl.c:1007)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842
# --> 843             retries = retries.increment(
#     844                 method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     518             reason = error or ResponseError(cause)
# --> 519             raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     520
#
# MaxRetryError: HTTPSConnectionPool(host='www.mse.com.mk', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.mse.com.mk'. (_ssl.c:1007)")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-88-9c468033694c> in <cell line: 15>()
#      13 # Example news URL from Macedonian Stock Exchange (replace with actual URL)
#      14 news_url = 'https://www.mse.com.mk'
# ---> 15 news_text = get_news(news_url)
#      16
#      17 sentiment = analyze_sentiment(news_text)
#
# <ipython-input-88-9c468033694c> in get_news(url)
#       3
#       4 def get_news(url):
# ----> 5     response = requests.get(url)
#       6     soup = BeautifulSoup(response.text, 'html.parser')
#       7
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     696             if isinstance(e.reason, _SSLError):
#     697                 # This branch is for urllib3 v1.22 and later.
# --> 698                 raise SSLError(e, request=request)
#     699
#     700             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='www.mse.com.mk', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.mse.com.mk'. (_ssl.c:1007)")))

# %%
import requests
from bs4 import BeautifulSoup

def get_news(url):
    response = requests.get(url, verify=False)
    soup = BeautifulSoup(response.text, 'html.parser')

    paragraphs = soup.find_all('p')
    news_content = " ".join([p.text for p in paragraphs])
    return news_content

news_url = 'https://www.mse.mk/daily/stats/symbolhistory/REPL?fbclid=PAY2xjawGbDElleHRuA2FlbQIxMAABprOfCGU-01uiZk2RriHFzXLGEXhqaSc-6G_y1BCYrFYHRJYrgYPIJzASeA_aem_c2NpwdUNW8BydaygLuxxkQ'
news_text = get_news(news_url)
print(news_text)
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.mse.mk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Price list 12/26/2024 Date period cannot exceed 365  days.
#                             Copyright © 2008 Macedonian Stock Exchange, Inc. All rights reserved.

# %%
import yfinance as yf

def get_historical_data(stock_symbol):
    stock = yf.Ticker(stock_symbol)
    historical_data = stock.history(period="10y")

    print(historical_data)

get_historical_data('TSLA')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2014-12-26 00:00:00-05:00   14.767333   15.233333   14.766667   15.188000
# 2014-12-29 00:00:00-05:00   15.126667   15.194000   14.934667   15.047333
# 2014-12-30 00:00:00-05:00   14.932667   15.043333   14.760000   14.815333
# 2014-12-31 00:00:00-05:00   14.872667   15.045333   14.816667   14.827333
# 2015-01-02 00:00:00-05:00   14.858000   14.883333   14.217333   14.620667
# ...                               ...         ...         ...         ...
# 2024-12-19 00:00:00-05:00  451.880005  456.359985  420.019989  436.170013
# 2024-12-20 00:00:00-05:00  425.510010  447.079987  417.640015  421.059998
# 2024-12-23 00:00:00-05:00  431.000000  434.510010  415.410004  430.600006
# 2024-12-24 00:00:00-05:00  435.899994  462.779999  435.140015  462.279999
# 2024-12-26 00:00:00-05:00  465.149994  465.329895  452.000000  454.214294
#
#                               Volume  Dividends  Stock Splits
# Date
# 2014-12-26 00:00:00-05:00   49905000        0.0           0.0
# 2014-12-29 00:00:00-05:00   42037500        0.0           0.0
# 2014-12-30 00:00:00-05:00   43548000        0.0           0.0
# 2014-12-31 00:00:00-05:00   34462500        0.0           0.0
# 2015-01-02 00:00:00-05:00   71466000        0.0           0.0
# ...                              ...        ...           ...
# 2024-12-19 00:00:00-05:00  118566100        0.0           0.0
# 2024-12-20 00:00:00-05:00  132216200        0.0           0.0
# 2024-12-23 00:00:00-05:00   72698100        0.0           0.0
# 2024-12-24 00:00:00-05:00   59551800        0.0           0.0
# 2024-12-26 00:00:00-05:00   36874409        0.0           0.0
#
# [2517 rows x 7 columns]

# %%
import yfinance as yf
import pandas as pd

def get_historical_data(stock_symbol):
    stock = yf.Ticker(stock_symbol)
    historical_data = stock.history(period="10y")
    print(historical_data.head())

    historical_data.to_csv(f"{stock_symbol}_historical_data.csv")

    return historical_data

data = get_historical_data('TSLA')
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2014-12-26 00:00:00-05:00  14.767333  15.233333  14.766667  15.188000
# 2014-12-29 00:00:00-05:00  15.126667  15.194000  14.934667  15.047333
# 2014-12-30 00:00:00-05:00  14.932667  15.043333  14.760000  14.815333
# 2014-12-31 00:00:00-05:00  14.872667  15.045333  14.816667  14.827333
# 2015-01-02 00:00:00-05:00  14.858000  14.883333  14.217333  14.620667
#
#                              Volume  Dividends  Stock Splits
# Date
# 2014-12-26 00:00:00-05:00  49905000        0.0           0.0
# 2014-12-29 00:00:00-05:00  42037500        0.0           0.0
# 2014-12-30 00:00:00-05:00  43548000        0.0           0.0
# 2014-12-31 00:00:00-05:00  34462500        0.0           0.0
# 2015-01-02 00:00:00-05:00  71466000        0.0           0.0

# %%
import ta

def calculate_technical_indicators(data):
    data['RSI'] = ta.momentum.RSIIndicator(data['Close'], window=14).rsi()

    data['SMA_50'] = data['Close'].rolling(window=50).mean()
    data['SMA_200'] = data['Close'].rolling(window=200).mean()

    data['EMA_50'] = data['Close'].ewm(span=50, adjust=False).mean()

    print(data[['Close', 'RSI', 'SMA_50', 'SMA_200', 'EMA_50']].tail())

    return data

data_with_indicators = calculate_technical_indicators(data)
# Out:
#                                 Close        RSI    SMA_50    SMA_200  \
# Date
# 2024-12-19 00:00:00-05:00  436.170013  65.897404  316.9278  229.75665
# 2024-12-20 00:00:00-05:00  421.059998  60.753979  320.5736  230.96870
# 2024-12-23 00:00:00-05:00  430.600006  62.731818  324.8296  232.24500
# 2024-12-24 00:00:00-05:00  462.279999  68.422829  329.6920  233.66755
# 2024-12-26 00:00:00-05:00  454.359985  65.720862  334.3878  235.05165
#
#                                EMA_50
# Date
# 2024-12-19 00:00:00-05:00  339.585171
# 2024-12-20 00:00:00-05:00  342.780262
# 2024-12-23 00:00:00-05:00  346.224174
# 2024-12-24 00:00:00-05:00  350.775383
# 2024-12-26 00:00:00-05:00  354.837524

# %%
def generate_trade_signals(data):
    data['Signal'] = 0

    data['Signal'][data['Close'] > data['SMA_50']] = 1
    data['Signal'][data['Close'] < data['SMA_50']] = -1

    print(data[['Close', 'SMA_50', 'Signal']].tail())
    return data

data_with_signals = generate_trade_signals(data_with_indicators)
# Out:
#                                 Close    SMA_50  Signal
# Date
# 2024-12-19 00:00:00-05:00  436.170013  316.9278       1
# 2024-12-20 00:00:00-05:00  421.059998  320.5736       1
# 2024-12-23 00:00:00-05:00  430.600006  324.8296       1
# 2024-12-24 00:00:00-05:00  462.279999  329.6920       1
# 2024-12-26 00:00:00-05:00  454.359985  334.3878       1
# <ipython-input-94-ffc5c502931b>:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['Signal'][data['Close'] > data['SMA_50']] = 1  # Buy signal
# <ipython-input-94-ffc5c502931b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Signal'][data['Close'] > data['SMA_50']] = 1  # Buy signal
# <ipython-input-94-ffc5c502931b>:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['Signal'][data['Close'] < data['SMA_50']] = -1  # Sell signal
# <ipython-input-94-ffc5c502931b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Signal'][data['Close'] < data['SMA_50']] = -1  # Sell signal

# %%
from textblob import TextBlob

def analyze_sentiment(news):
    sentiment_scores = []

    for article in news:
        blob = TextBlob(article)
        sentiment_scores.append(blob.sentiment.polarity)

    return sentiment_scores

news_articles = [
    "Tesla stock soars after strong earnings report.",
    "Tesla faces challenges as production delays continue."
]
sentiment_scores = analyze_sentiment(news_articles)

print(sentiment_scores)
# Out:
# [0.4333333333333333, 0.0]

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

def preprocess_for_lstm(data):
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data[['Close']])

    X = []
    y = []

    for i in range(60, len(scaled_data)):
        X.append(scaled_data[i-60:i, 0])
        y.append(scaled_data[i, 0])

    X = np.array(X)
    y = np.array(y)

    X = np.reshape(X, (X.shape[0], X.shape[1], 1))

    return X, y, scaler

def create_lstm_model():
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=(60, 1)))
    model.add(LSTM(units=50, return_sequences=False))
    model.add(Dense(units=1))
    model.compile(optimizer='adam', loss='mean_squared_error')

    return model

def train_lstm_model(X, y):
    model = create_lstm_model()
    model.fit(X, y, epochs=10, batch_size=32)
    return model

X, y, scaler = preprocess_for_lstm(data)
lstm_model = train_lstm_model(X, y)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - loss: 0.0263
# Epoch 2/10
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - loss: 9.3220e-04
# Epoch 3/10
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - loss: 9.6114e-04
# Epoch 4/10
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 7.4719e-04
# Epoch 5/10
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 6.0728e-04
# Epoch 6/10
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 6.3079e-04
# Epoch 7/10
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 5.7788e-04
# Epoch 8/10
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 5.5857e-04
# Epoch 9/10
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 5.3610e-04
# Epoch 10/10
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 6.2588e-04

# %%
import numpy as np
import matplotlib.pyplot as plt

def make_predictions(model, X_test, scaler):
    predicted_stock_price = model.predict(X_test)

    predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

    return predicted_stock_price

train_size = int(len(data) * 0.8)
train_data = data[:train_size]
test_data = data[train_size:]

X_test, y_test, _ = preprocess_for_lstm(test_data)

predicted_prices = make_predictions(lstm_model, X_test, scaler)

plt.figure(figsize=(10,6))
plt.plot(test_data.index[-len(predicted_prices):], test_data['Close'].iloc[-len(predicted_prices):], color='blue', label='Actual Price')
plt.plot(test_data.index[-len(predicted_prices):], predicted_prices, color='red', label='Predicted Price')
plt.title('Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

def evaluate_model(y_test, predicted_prices):
    mse = mean_squared_error(y_test, predicted_prices)
    mae = mean_absolute_error(y_test, predicted_prices)
    print(f'Mean Squared Error (MSE): {mse}')
    print(f'Mean Absolute Error (MAE): {mae}')

evaluate_model(y_test, predicted_prices)
# Out:
# Mean Squared Error (MSE): 29621.00502679762
# Mean Absolute Error (MAE): 158.99783727998047

# %%
residuals = predicted_prices - y_test
plt.figure(figsize=(10,6))
plt.plot(test_data.index[-len(predicted_prices):], residuals, color='green')
plt.title('Residuals of Predictions')
plt.xlabel('Date')
plt.ylabel('Residual (Predicted - Actual)')
plt.show()

# %%
pip install ta
# Out:
# Requirement already satisfied: ta in /usr/local/lib/python3.10/dist-packages (0.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ta) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ta) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->ta) (1.17.0)

# %%
import pandas as pd
import ta

# %%
df['SMA_10'] = df['Close'].rolling(window=10).mean()
df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()

df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=14).rsi()
df['MACD'] = ta.trend.MACD(df['Close']).macd()
df['Stochastic'] = ta.momentum.StochasticOscillator(df['High'], df['Low'], df['Close'], window=14).stoch()

df['ADX'] = ta.trend.ADXIndicator(df['High'], df['Low'], df['Close'], window=14).adx()
df['MFI'] = ta.volume.MFIIndicator(df['High'], df['Low'], df['Close'], df['Volume'], window=14).money_flow_index()
df['CCI'] = ta.trend.CCIIndicator(df['High'], df['Low'], df['Close'], window=14).cci()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-49196fc63630> in <cell line: 2>()
#       1 # Moving Averages (SMA and EMA)
# ----> 2 df['SMA_10'] = df['Close'].rolling(window=10).mean()  # Simple Moving Average for 10 periods
#       3 df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()  # Exponential Moving Average for 10 periods
#       4
#       5 # Oscillators
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Close'

# %%
print(df.columns)
# Out:
# Index(['Last trade price', 'Max', 'Min', 'Avg. Price', '%chg.', 'Volume',
#        'Turnover in BEST in denars', 'Total turnover in denars', 'Date',
#        'Price Change', 'Gain', 'Loss', 'Avg Gain', 'Avg Loss', 'RS', 'RSI'],
#       dtype='object')

# %%
df['SMA_10'] = df['Last trade price'].rolling(window=10).mean()
df['EMA_10'] = df['Last trade price'].ewm(span=10, adjust=False).mean()

df['RSI'] = ta.momentum.RSIIndicator(df['Last trade price'], window=14).rsi()
df['MACD'] = ta.trend.MACD(df['Last trade price']).macd()
df['Stochastic'] = ta.momentum.StochasticOscillator(df['High'], df['Low'], df['Last trade price'], window=14).stoch()

df['ADX'] = ta.trend.ADXIndicator(df['High'], df['Low'], df['Last trade price'], window=14).adx()
df['MFI'] = ta.volume.MFIIndicator(df['High'], df['Low'], df['Last trade price'], df['Volume'], window=14).money_flow_index()
df['CCI'] = ta.trend.CCIIndicator(df['High'], df['Low'], df['Last trade price'], window=14).cci()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'High'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-90431bdaea1a> in <cell line: 8>()
#       6 df['RSI'] = ta.momentum.RSIIndicator(df['Last trade price'], window=14).rsi()  # Relative Strength Index
#       7 df['MACD'] = ta.trend.MACD(df['Last trade price']).macd()  # Moving Average Convergence Divergence
# ----> 8 df['Stochastic'] = ta.momentum.StochasticOscillator(df['High'], df['Low'], df['Last trade price'], window=14).stoch()  # Stochastic Oscillator
#       9
#      10 # Additional Indicators
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'High'

# %%
df['SMA_10'] = df['Last trade price'].rolling(window=10).mean()
df['EMA_10'] = df['Last trade price'].ewm(span=10, adjust=False).mean()

# Oscillators
df['RSI'] = ta.momentum.RSIIndicator(df['Last trade price'], window=14).rsi()
df['MACD'] = ta.trend.MACD(df['Last trade price']).macd()
df['Stochastic'] = ta.momentum.StochasticOscillator(df['Max'], df['Min'], df['Last trade price'], window=14).stoch()

df['ADX'] = ta.trend.ADXIndicator(df['Max'], df['Min'], df['Last trade price'], window=14).adx()
df['MFI'] = ta.volume.MFIIndicator(df['Max'], df['Min'], df['Last trade price'], df['Volume'], window=14).money_flow_index()
df['CCI'] = ta.trend.CCIIndicator(df['Max'], df['Min'], df['Last trade price'], window=14).cci()

# %%
df['Signal'] = 0
df.loc[df['RSI'] < 30, 'Signal'] = 1
df.loc[df['RSI'] > 70, 'Signal'] = -1

# %%
df['Signal_1_day'] = df['Signal'].shift(0)
df['Signal_1_week'] = df['Signal'].rolling(window=7).mean()
df['Signal_1_month'] = df['Signal'].rolling(window=30).mean()

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.67.1)

# %%
from textblob import TextBlob
import requests
from bs4 import BeautifulSoup

# %%
def get_news_from_url(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    headlines = soup.find_all('h2')
    return [headline.text for headline in headlines]

news_articles = get_news_from_url('https://www.mse.mk/daily/stats/symbolhistory/REPL?fbclid=PAY2xjawGbDElleHRuA2FlbQIxMAABprOfCGU-01uiZk2RriHFzXLGEXhqaSc-6G_y1BCYrFYHRJYrgYPIJzASeA_aem_c2NpwdUNW8BydaygLuxxkQ')  # Replace with real news URL

# %%
def analyze_sentiment(text):
    analysis = TextBlob(text)

    return analysis.sentiment.polarity

sentiments = [analyze_sentiment(article) for article in news_articles]

recommendations = ['Buy' if sentiment > 0 else 'Sell' for sentiment in sentiments]

# %%
df['News_Sentiment'] = sum(sentiments) / len(sentiments)
df['Final_Signal'] = df['Signal'] * (df['News_Sentiment'] > 0).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-112-4c50adf9fffc> in <cell line: 1>()
# ----> 1 df['News_Sentiment'] = sum(sentiments) / len(sentiments)  # Average sentiment from news articles
#       2 df['Final_Signal'] = df['Signal'] * (df['News_Sentiment'] > 0).astype(int)
#
# ZeroDivisionError: division by zero

# %%
if len(sentiments) > 0:
    df['News_Sentiment'] = sum(sentiments) / len(sentiments)
else:
    df['News_Sentiment'] = 0

# %%
df['News_Sentiment'] = sum(sentiments) / len(sentiments)
df['Final_Signal'] = df['Signal'] * (df['News_Sentiment'] > 0).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-117-4c50adf9fffc> in <cell line: 1>()
# ----> 1 df['News_Sentiment'] = sum(sentiments) / len(sentiments)  # Average sentiment from news articles
#       2 df['Final_Signal'] = df['Signal'] * (df['News_Sentiment'] > 0).astype(int)
#
# ZeroDivisionError: division by zero

# %%
print(sentiments)
if len(sentiments) > 0:
    df['News_Sentiment'] = sum(sentiments) / len(sentiments)
else:
    df['News_Sentiment'] = 0
# Out:
# []

# %%
from textblob import TextBlob

sentiment = TextBlob(news_article).sentiment.polarity
sentiments.append(sentiment)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-668c64b8be13> in <cell line: 4>()
#       2
#       3 # Example of sentiment extraction
# ----> 4 sentiment = TextBlob(news_article).sentiment.polarity
#       5 sentiments.append(sentiment)  # Collect sentiment values for each article
#
# NameError: name 'news_article' is not defined

# %%
news_article = "The stock market is doing well today with rising prices and high volume."

# %%
from textblob import TextBlob

# List of sample news articles
news_articles = [
    "The stock market is doing well today with rising prices.",
    "The market is facing challenges due to uncertain economic conditions.",
    "New technology is boosting stocks in the tech industry."
]

sentiments = []

for news_article in news_articles:
    sentiment = TextBlob(news_article).sentiment.polarity
    sentiments.append(sentiment)

print(sentiments)
# Out:
# [0.0, 0.037500000000000006, 0.13636363636363635]

# %%
news_articles = [
    "The stock market is doing well today with rising prices.",
    "",
    "The market is facing challenges due to uncertain economic conditions."
]

sentiments = []

for news_article in news_articles:
    if news_article.strip():
        sentiment = TextBlob(news_article).sentiment.polarity
        sentiments.append(sentiment)

print(sentiments)
# Out:
# [0.0, 0.037500000000000006]

# %%
if sentiments:
    avg_sentiment = sum(sentiments) / len(sentiments)
    print(f"Average Sentiment: {avg_sentiment}")
else:
    print("No sentiments to calculate.")
# Out:
# Average Sentiment: 0.018750000000000003

# %%
if sentiments:
    df['News_Sentiment'] = sum(sentiments) / len(sentiments)
else:
    df['News_Sentiment'] = 0

df['Final_Signal'] = df['Signal'] * (df['News_Sentiment'] > 0).astype(int)

# %%
df['News_Sentiment'] = sum(sentiments) / len(sentiments)
df['Final_Signal'] = df['Signal'] * (df['News_Sentiment'] > 0).astype(int)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
import numpy as np

X = df[['Last trade price']].values
X = X.reshape((X.shape[0], 1, X.shape[1]))

train_size = int(len(X) * 0.7)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = df['Last trade price'][:train_size], df['Last trade price'][train_size:]

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=10, batch_size=32)

predictions = model.predict(X_test)

from sklearn.metrics import mean_squared_error, mean_absolute_error
mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 219425056.0000
# Epoch 2/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 219416112.0000
# Epoch 3/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 219679456.0000
# Epoch 4/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 219246400.0000
# Epoch 5/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 219715008.0000
# Epoch 6/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 219652000.0000
# Epoch 7/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 219289600.0000
# Epoch 8/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 219495664.0000
# Epoch 9/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 219507008.0000
# Epoch 10/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 219457312.0000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step
# Mean Squared Error (MSE): 219230492.38260993
# Mean Absolute Error (MAE): 14805.711890250917

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

df['Last trade price'] = df['Last trade price'].astype(float)

scaler = MinMaxScaler(feature_range=(0, 1))
df['Scaled_Price'] = scaler.fit_transform(df[['Last trade price']])

X = df[['Scaled_Price']].values
X = X.reshape((X.shape[0], 1, X.shape[1]))

train_size = int(len(X) * 0.7)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = df['Scaled_Price'][:train_size], df['Scaled_Price'][train_size:]

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=50, batch_size=32)

predictions = model.predict(X_test)

predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

mse = mean_squared_error(y_test_actual, predictions)
mae = mean_absolute_error(y_test_actual, predictions)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.1950
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1656
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1282
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0868
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0642
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0441
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0261
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0108
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0041
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0024
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0040
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0045
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023
# Epoch 20/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036
# Epoch 21/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031
# Epoch 22/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0045
# Epoch 23/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025
# Epoch 24/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035
# Epoch 25/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020
# Epoch 26/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030
# Epoch 27/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034
# Epoch 28/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032
# Epoch 29/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036
# Epoch 30/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026
# Epoch 31/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024
# Epoch 32/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025
# Epoch 33/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028
# Epoch 34/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021
# Epoch 35/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025
# Epoch 36/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019
# Epoch 37/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020
# Epoch 38/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025
# Epoch 39/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024
# Epoch 40/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026
# Epoch 41/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025
# Epoch 42/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020
# Epoch 43/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021
# Epoch 44/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019
# Epoch 45/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022
# Epoch 46/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025
# Epoch 47/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018
# Epoch 48/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021
# Epoch 49/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020
# Epoch 50/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014
# WARNING:tensorflow:5 out of the last 21 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d7d03235b40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-e7d0e558cb3f> in <cell line: 40>()
#      38 # Inverse scale the predictions and actual values
#      39 predictions = scaler.inverse_transform(predictions)
# ---> 40 y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
#      41
#      42 # Evaluate the model (MSE and MAE)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %%
predictions = scaler.inverse_transform(predictions)

y_test_actual = scaler.inverse_transform(np.array(y_test).reshape(-1, 1))

mse = mean_squared_error(y_test_actual, predictions)
mae = mean_absolute_error(y_test_actual, predictions)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Mean Squared Error (MSE): 35115594722984.465
# Mean Absolute Error (MAE): 5925565.83068783

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, label='Actual', color='blue')
plt.plot(predictions, label='Predicted', color='red')
plt.title('Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, label='Actual', color='blue')
plt.plot(predictions, label='Predicted', color='red')
plt.title('Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
df['SMA'] = df['Last trade price'].rolling(window=30).mean()

df['EMA'] = df['Last trade price'].ewm(span=30, adjust=False).mean()

# %%
import ta
df['RSI'] = ta.momentum.RSIIndicator(df['Last trade price']).rsi()
df['MACD'] = ta.trend.MACD(df['Last trade price']).macd()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(df['Last trade price'], label='Stock Price')
plt.plot(df['SMA'], label='SMA')
plt.plot(df['EMA'], label='EMA')
plt.legend()
plt.show()

# %%
from textblob import TextBlob
def sentiment_analysis(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['Last trade price']], df['Last trade price'], test_size=0.3, shuffle=False)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 219640816.0000
# Epoch 2/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 219915024.0000
# Epoch 3/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 219798816.0000
# Epoch 4/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 219463264.0000
# Epoch 5/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 219725232.0000
# Epoch 6/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 219423008.0000
# Epoch 7/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 219285664.0000
# Epoch 8/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 219436608.0000
# Epoch 9/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 219423744.0000
# Epoch 10/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 219319056.0000

# %%
y_pred = model.predict(X_test)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d7d026c91b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 219230357.0849526

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual Prices')
plt.plot(y_pred, label='Predicted Prices')
plt.legend()
plt.show()
